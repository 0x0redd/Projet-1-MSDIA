# %% [markdown]
# # hand Writen — Feature Parameter Selection + Benchmark
# ## Phase 1: Optimal GLCM · LBP · DWT · HOG parameters via Class-Separability Metrics
# ## Phase 2: Full SVM · KNN · RF Benchmark with optimal parameters
#
# ---
#
# ### Strategy
#
# Training a full classifier for every parameter combination is expensive.
# Instead we use three **classifier-free separability metrics** to score each
# feature configuration in seconds:
#
# | Metric | What it measures | Why useful |
# |--------|-----------------|------------|
# | **Fisher's Discriminant Ratio (FDR)** | Between-class variance ÷ within-class variance per feature (averaged) | High FDR = features naturally cluster by class |
# | **Mutual Information (MI)** | Statistical dependency between each feature and the class label | Captures non-linear relationships |
# | **Davies-Bouldin Index (DBI)** | Cluster compactness & separation in feature space | Lower = better separated classes |
#
# Once the best parameters are selected, a single model benchmark is run with those parameters.
#
# ### Parameters explored
#
# | Feature | Parameters |
# |---------|-----------|
# | **GLCM** | distances, angles, levels, symmetric |
# | **LBP** | P (sampling points), R (radius), method |
# | **DWT** | wavelet family, decomposition levels |
# | **HOG** | orientations, pixels per cell, cells per block, block norm |

# %% [markdown]
# ## 1. Setup

# %%
# Run once when setting up the env, then RESTART THE KERNEL before imports.
# Re-running pip without restart can break scipy/sklearn (AttributeError on scipy.sparse.linalg).
# %pip install -q numpy pandas matplotlib seaborn scikit-learn scikit-image scipy pywavelets tqdm pillow joblib kagglehub
print("If packages were installed or upgraded: Kernel → Restart, then run from §1 imports onward (skip this cell).")

# %%
import time, warnings, itertools, hashlib
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from tqdm.auto import tqdm
from pathlib import Path

from scipy.stats import skew, kurtosis

from sklearn.preprocessing import StandardScaler, label_binarize, MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.feature_selection import mutual_info_classif, VarianceThreshold
from sklearn.metrics import (accuracy_score, f1_score, precision_score,
                             recall_score, confusion_matrix, davies_bouldin_score,
                             silhouette_score)
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from skimage.io import imread
from skimage.color import rgb2gray
from skimage.transform import resize
from skimage.filters import gaussian
from skimage import exposure
from skimage.feature import hog, local_binary_pattern, graycomatrix, graycoprops
import pywt

warnings.filterwarnings("ignore")
SEED = 42
np.random.seed(SEED)
sns.set_theme(style="whitegrid", font_scale=1.05)

print("All imports OK.")

# %% [markdown]
# ## 2. Configuration
#
# Edit the parameter grids here to control which values are explored.

# %%
from pathlib import Path

import kagglehub

# Download latest version
path = kagglehub.dataset_download("olafkrastovski/handwritten-digits-0-9")

print("Path to dataset files:", path)

# ── Dataset ────────────────────────────────────────────────────────────────
# DATASET_ROOT = Path("Dataset/BrainTumorDetection&Classification/BrainTumorDetection&Classification") # Original line
DATASET_DIR  = path # Modified to use the downloaded dataset path directly
TARGET_SIZE  = (128, 128)
USE_CLAHE    = True
TEST_SIZE    = 0.20
MAX_SAMPLES_PER_CLASS = None   # set e.g. 400 for faster runs

# ── Local cache (faster reruns) ───────────────────────────────────────────
CACHE_DIR = Path("cache/handwritten_digits") # Changed cache dir for clarity
CACHE_DIR.mkdir(parents=True, exist_ok=True)
FORCE_RECOMPUTE_CACHE = False

# Fine-grained checkpoint folders (phase / cell level)
PHASE_CACHE_DIR = CACHE_DIR / "phase_artifacts"
CELL_CACHE_DIR = CACHE_DIR / "cell_artifacts"
PHASE_CACHE_DIR.mkdir(parents=True, exist_ok=True)
CELL_CACHE_DIR.mkdir(parents=True, exist_ok=True)

# Toggle to reuse saved outputs for heavy cells
USE_PHASE_CACHE = True

# Phase 1 bundle (run Phase 2 in a fresh kernel without re-scanning grids)
PHASE1_BUNDLE_PATH = PHASE_CACHE_DIR / "phase1_bundle.joblib"
PHASE1_HISTORY_PATH = PHASE_CACHE_DIR / "phase1_runs.csv"
PHASE1_MANIFEST_PATH = PHASE_CACHE_DIR / "phase1_runs_manifest.csv"
PHASE1_BEST_JSON_PATH = PHASE_CACHE_DIR / "phase1_best.json"
PHASE1_FULL_SEARCH_DIR = PHASE_CACHE_DIR / "phase1_full_search_archive"
PHASE1_APPEND_FULL_SEARCH_HISTORY = True
PHASE1_SKIP_IF_OUTCOME_UNCHANGED = True
SKIP_PHASE1_SCANS_IF_BUNDLE_MATCHES = True
PHASE1_SKIP_DUPLICATE_HISTORY_ROWS = True
LOAD_PHASE1_BUNDLE_FOR_PHASE2 = False  # True after restart: load BEST_* from disk

PHASE1_FULL_SEARCH_DIR.mkdir(parents=True, exist_ok=True)
PHASE1_SCAN_CACHE_DIR = PHASE_CACHE_DIR / "phase1_scans"
PHASE1_SCAN_CACHE_DIR.mkdir(parents=True, exist_ok=True)
USE_PHASE1_SCAN_CACHE = True       # save/load each GLCM/LBP/DWT/HOG grid search separately
FORCE_PHASE1_RESCAN = False        # True = ignore per-scan caches and re-run all grids
RUN_PHASE1_VIZ = False             # True = plot top-10 configs per feature (slow on reruns)

# ── Output directory for all figures ───────────────────────────────────────
OUTPUT_DIR = Path("output")
OUTPUT_DIR.mkdir(exist_ok=True)

# ══════════════════════════════════════════════════════════════════════════
# PARAMETER GRIDS — edit these to explore different values
# ══════════════════════════════════════════════════════════════════════════

# ── GLCM parameters ───────────────────────────────────────────────────────
# distances : pixel offsets — small distances capture fine texture,
#             large distances capture coarser structure
# angles    : directions to compute co-occurrence (radians)
# levels    : number of grey-level bins (higher = finer but noisier)
# symmetric : whether to average P(i,j) with P(j,i)
GLCM_GRID = {
    "distances": [
        [1],
        [1, 2],
        [1, 2, 4],
        [1, 2, 4, 8],
        [2, 4],
        [4, 8],
    ],
    "angles": [
        [0],
        [0, np.pi/2],
        [0, np.pi/4, np.pi/2, 3*np.pi/4],          # standard 4 angles
        [0, np.pi/6, np.pi/3, np.pi/2, 2*np.pi/3, 5*np.pi/6],  # 6 angles
    ],
    "levels": [64, 128, 256],
    "symmetric": [True, False],
}

# ── LBP parameters ────────────────────────────────────────────────────────
# P      : number of sampling points around each pixel
#          more points = finer texture description, longer vector
# R      : radius of the circular neighbourhood in pixels
# method : "uniform"     — only patterns with ≤2 bit transitions (compact)
#          "nri_uniform" — non-rotation-invariant uniform patterns
#          "ror"         — rotation-invariant but not uniform
#          "default"     — standard LBP (all 2^P patterns)
LBP_GRID = {
    "P": [8, 12, 16, 24],
    "R": [1, 2, 3],
    "method": ["uniform", "nri_uniform", "ror"],
}

# ── DWT parameters ────────────────────────────────────────────────────────
# wavelet : wavelet family — affects smoothness and frequency localisation
#   haar  : simplest, discontinuous
#   db1-4 : Daubechies family (db1 = haar); more vanishing moments = smoother
#   sym2  : Symlets (near-symmetric Daubechies)
#   coif1 : Coiflets (higher vanishing moments, good for smooth signals)
#   bior1.3: Biorthogonal (symmetric, used in JPEG 2000)
# level   : decomposition depth — more levels = coarser frequency bands
#           but sub-bands become very small on 128×128 images (max ~5 levels)
DWT_GRID = {
    "wavelet": ["haar", "db1", "db2", "db4", "sym2", "coif1", "bior1.3"],
    "level":   [1, 2, 3],
}

# ── HOG parameters ────────────────────────────────────────────────────────
# orientations    : number of gradient direction bins
# pixels_per_cell : spatial granularity of local histograms
# cells_per_block : normalization neighborhood size
# block_norm      : block normalization strategy
HOG_GRID = {
    "orientations": [6, 9, 12],
    "pixels_per_cell": [(8, 8), (16, 16)],
    "cells_per_block": [(2, 2), (3, 3)],
    "block_norm": ["L2-Hys"],
}

# Count total configurations
n_glcm = (len(GLCM_GRID["distances"]) * len(GLCM_GRID["angles"]) *
           len(GLCM_GRID["levels"])    * len(GLCM_GRID["symmetric"]))
n_lbp  = len(LBP_GRID["P"]) * len(LBP_GRID["R"]) * len(LBP_GRID["method"])
n_dwt  = len(DWT_GRID["wavelet"]) * len(DWT_GRID["level"])
n_hog  = (len(HOG_GRID["orientations"]) * len(HOG_GRID["pixels_per_cell"]) *
          len(HOG_GRID["cells_per_block"]) * len(HOG_GRID["block_norm"]))

print(f"GLCM configurations : {n_glcm}")
print(f"LBP  configurations : {n_lbp}")
print(f"DWT  configurations : {n_dwt}")
print(f"HOG  configurations : {n_hog}")
print(f"Total feature configs: {n_glcm + n_lbp + n_dwt + n_hog}")

# %% [markdown]
# ## 3. Preprocessing & Data Loading

# %%
def crop_black(img, thr=0.05):
    mask = img > thr
    if not np.any(mask): return img
    ys, xs = np.where(mask)
    return img[ys.min():ys.max()+1, xs.min():xs.max()+1]

def preprocess_mri(img):
    if img.ndim == 3: img = rgb2gray(img)
    img = img.astype(np.float32)
    if img.max() > 1.0: img /= 255.0
    img = crop_black(img)
    img = resize(img, TARGET_SIZE, anti_aliasing=True, preserve_range=True).astype(np.float32)
    img = gaussian(img, sigma=0.5, preserve_range=True).astype(np.float32)
    mn, mx = img.min(), img.max()
    img = (img - mn) / (mx - mn + 1e-9)
    if USE_CLAHE:
        img = np.clip(exposure.equalize_adapthist(img, clip_limit=0.02), 0, 1)
    return img.astype(np.float32)

def load_dataset(dataset_dir, max_per_class=None):
    dataset_dir = Path(dataset_dir)
    class_names = sorted([d.name for d in dataset_dir.iterdir() if d.is_dir()])
    rng = np.random.default_rng(SEED)
    X_list, y_list = [], []
    for idx, cls in enumerate(class_names):
        paths = [p for p in (dataset_dir/cls).iterdir()
                 if p.suffix.lower() in {".jpg",".jpeg",".png",".bmp"}]
        if max_per_class and len(paths) > max_per_class:
            paths = [paths[i] for i in rng.choice(len(paths), max_per_class, replace=False)]
        for p in tqdm(paths, desc=f"  {cls}"):
            try:
                X_list.append(preprocess_mri(imread(p)))
                y_list.append(idx)
            except Exception: pass
    return np.stack(X_list).astype(np.float32), np.array(y_list, np.int32), class_names

cache_tag = f"sz{TARGET_SIZE[0]}x{TARGET_SIZE[1]}_clahe{int(USE_CLAHE)}_test{TEST_SIZE}_max{MAX_SAMPLES_PER_CLASS}"
cache_hash = hashlib.md5(cache_tag.encode("utf-8")).hexdigest()[:10]
dataset_cache_path = CACHE_DIR / f"dataset_{cache_hash}.npz"

if dataset_cache_path.exists() and not FORCE_RECOMPUTE_CACHE:
    print(f"Loading dataset from cache: {dataset_cache_path}")
    ds = np.load(dataset_cache_path, allow_pickle=True)
    X_train_raw = ds["X_train_raw"]
    X_test_raw = ds["X_test_raw"]
    y_train = ds["y_train"]
    y_test = ds["y_test"]
    class_names = list(ds["class_names"])
    X_all = np.concatenate([X_train_raw, X_test_raw], axis=0)
    y_all = np.concatenate([y_train, y_test], axis=0)
else:
    print("Loading dataset from images …")
    X_all, y_all, class_names = load_dataset(DATASET_DIR, MAX_SAMPLES_PER_CLASS)
    X_train_raw, X_test_raw, y_train, y_test = train_test_split(
        X_all, y_all, test_size=TEST_SIZE, random_state=SEED, stratify=y_all
    )
    np.savez_compressed(
        dataset_cache_path,
        X_train_raw=X_train_raw,
        X_test_raw=X_test_raw,
        y_train=y_train,
        y_test=y_test,
        class_names=np.array(class_names, dtype=object),
    )
    print(f"Saved dataset cache: {dataset_cache_path}")

n_classes = len(class_names)

print(f"Classes ({n_classes}): {class_names}")
print(f"Train: {X_train_raw.shape}   Test: {X_test_raw.shape}")

# ── Dataset plotting: class distribution + sample images ─────────────────
train_counts = np.bincount(y_train, minlength=n_classes)
test_counts = np.bincount(y_test, minlength=n_classes)

fig, axes = plt.subplots(1, 2, figsize=(14, 4.5))
x = np.arange(n_classes)
width = 0.38
axes[0].bar(x - width / 2, train_counts, width=width, label="Train")
axes[0].bar(x + width / 2, test_counts, width=width, label="Test")
axes[0].set_xticks(x)
axes[0].set_xticklabels(class_names, rotation=15)
axes[0].set_title("Class distribution")
axes[0].set_ylabel("Number of samples")
axes[0].legend()

n_show = min(12, len(X_train_raw))
idx = np.random.choice(len(X_train_raw), size=n_show, replace=False)
grid_rows, grid_cols = 3, 4
sample_fig = np.zeros((TARGET_SIZE[0] * grid_rows, TARGET_SIZE[1] * grid_cols), dtype=np.float32)
for k, i in enumerate(idx):
    r, c = divmod(k, grid_cols)
    y0, y1 = r * TARGET_SIZE[0], (r + 1) * TARGET_SIZE[0]
    x0, x1 = c * TARGET_SIZE[1], (c + 1) * TARGET_SIZE[1]
    sample_fig[y0:y1, x0:x1] = X_train_raw[i]
axes[1].imshow(sample_fig, cmap="gray")
axes[1].set_title("Preprocessed train sample mosaic")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Class-Separability Metrics
# ### Why not just use a classifier?
#
# Training even a simple KNN on every parameter combination would take hours.
# These three metrics evaluate feature quality in **milliseconds** by directly
# measuring how well the feature distributions separate the classes.
#
# ```
# Fisher's Discriminant Ratio (FDR)
#   = mean over all features of:
#       (between-class variance) / (within-class variance + ε)
#
#   → High FDR means class means are far apart relative to within-class spread
#   → Equivalent to the numerator of LDA's objective function
#
# Mutual Information (MI)
#   = average MI(feature_i ; class_label) over all features
#   → Captures non-linear relationships that FDR misses
#   → Scale-invariant — robust to feature magnitude differences
#
# Davies-Bouldin Index (DBI)  [lower = better]
#   = average ratio of (within-cluster scatter) to (between-cluster distance)
#     computed in the full feature space (using PCA to 20 dims for speed)
#   → Directly measures cluster quality in feature space
#   → Lower DBI = more compact, better-separated class clusters
# ```

# %%
def fisher_discriminant_ratio(X, y):
    # Compute the mean Fisher Discriminant Ratio across all features.
    # FDR = between-class variance / within-class variance.
    # A higher value means features separate classes better.
    classes = np.unique(y)
    grand_mean = X.mean(axis=0)
    n_features = X.shape[1]

    between = np.zeros(n_features)
    within  = np.zeros(n_features)

    for c in classes:
        Xc = X[y == c]
        n_c = len(Xc)
        class_mean = Xc.mean(axis=0)
        # Between-class: weighted distance of class mean from grand mean
        between += n_c * (class_mean - grand_mean) ** 2
        # Within-class: variance of samples inside this class
        within  += ((Xc - class_mean) ** 2).sum(axis=0)

    # Avoid division by zero with a small epsilon
    fdr_per_feature = between / (within + 1e-10)
    return float(np.mean(fdr_per_feature))


def mutual_information_score(X, y):
    # Average mutual information between each feature and the class label.
    # Uses sklearn's implementation which handles discrete classes automatically.
    # Returns a scalar: higher = features carry more information about the label.
    mi = mutual_info_classif(X, y, random_state=SEED, n_neighbors=5)
    return float(np.mean(mi))


def davies_bouldin(X, y, max_dim=20):
    # Davies-Bouldin Index on a PCA-reduced version of X.
    # Lower = better separated classes.
    # We reduce to max_dim components first for speed (avoids O(n²) in high-D).
    n_comp = min(max_dim, X.shape[1], X.shape[0] - 1)
    Xr = PCA(n_components=n_comp, random_state=SEED).fit_transform(X)
    return float(davies_bouldin_score(Xr, y))


def evaluate_features(X, y, label="", verbose=False):
    # Apply all three metrics; return a dict.
    # X should already be standardised for fair comparison across configs.
    sc  = StandardScaler()
    Xs  = sc.fit_transform(X)
    fdr = fisher_discriminant_ratio(Xs, y)
    mi  = mutual_information_score(Xs, y)
    dbi = davies_bouldin(Xs, y)
    if verbose:
        print(f"  {label:40s}  FDR={fdr:.4f}  MI={mi:.4f}  DBI={dbi:.4f}")
    return {"FDR": fdr, "MI": mi, "DBI": dbi}


# Quick sanity-check on a dummy random feature matrix
_X_dummy = np.random.randn(len(y_train), 20)
_res = evaluate_features(_X_dummy, y_train, "random baseline", verbose=True)
print("Sanity check passed — metrics computed successfully.")

# %% [markdown]
# ## 5. Parameterised Feature Extraction Functions

# %%
# ── GLCM extractor (fully parameterised) ──────────────────────────────────
def extract_glcm(images, distances, angles, levels, symmetric):
    # Compute GLCM-based texture features for a list of images.
    # distances : list of pixel offsets
    # angles    : list of angles in radians
    # levels    : number of grey-level bins
    # symmetric : whether to symmetrise the co-occurrence matrix
    #
    # Returns one row per image with 6 GLCM properties averaged over all
    # (distance, angle) pairs.
    props = ["contrast","dissimilarity","homogeneity","energy","correlation","ASM"]
    rows = []
    for img in images:
        # Quantize to [0, levels-1] so graycomatrix(levels=...) is valid.
        q = np.clip(np.floor(img * levels), 0, levels - 1).astype(np.uint8)
        glcm = graycomatrix(q, distances=distances, angles=angles,
                            levels=levels, symmetric=symmetric, normed=True)
        row = [graycoprops(glcm, p).mean() for p in props]
        rows.append(row)
    return np.array(rows, dtype=np.float32)


# ── LBP extractor (fully parameterised) ───────────────────────────────────
def extract_lbp(images, P, R, method):
    # Compute LBP histogram features for a list of images.
    # P      : number of circularly-symmetric neighbour set points
    # R      : radius of circle
    # method : LBP variant — affects number of unique patterns
    #   "uniform"     → P+2 bins  (patterns with ≤2 bit transitions)
    #   "nri_uniform" → P+2 bins  (non-rotation-invariant uniform)
    #   "ror"         → rotation-invariant codes; dense 2^P hist can explode
    #   "default"     → standard LBP (all 2^P patterns)
    #
    # Cap huge histograms for high P to avoid OOM while keeping fixed size.
    MAX_LBP_BINS = 4096
    if method in ("uniform", "nri_uniform"):
        n_bins = P + 2
        hist_range = (0, n_bins)
    else:
        full_bins = 2 ** P
        n_bins = min(full_bins, MAX_LBP_BINS)
        hist_range = (0, full_bins)

    rows = []
    for img in images:
        lbp = local_binary_pattern(img, P=P, R=R, method=method)
        hist, _ = np.histogram(lbp.ravel(), bins=n_bins, range=hist_range, density=True)
        rows.append(hist.astype(np.float32))
    return np.array(rows, dtype=np.float32)


# ── DWT extractor (fully parameterised) ───────────────────────────────────
def _band_stats(b):
    # Four statistics per wavelet sub-band:
    # mean (dc level), std (spread), energy (power), entropy (diversity)
    v = b.ravel().astype(np.float32)
    h, _ = np.histogram(v, bins=64, density=True)
    h = (h + 1e-12); h /= h.sum()
    return [v.mean(), v.std(), np.mean(v**2), -(h*np.log2(h)).sum()]

def extract_dwt(images, wavelet, level):
    # Apply multi-level 2-D DWT and collect statistics from every sub-band.
    # wavelet : wavelet family string (e.g. "db2", "haar")
    # level   : decomposition depth
    #   Level 1 → 4 sub-bands (LL, LH, HL, HH)
    #   Level 2 → 7 sub-bands (LL2, LH2, HL2, HH2, LH1, HL1, HH1)
    #   Level L → 3L+1 sub-bands total
    #
    # For each sub-band we extract 4 stats → 4*(3L+1) total features
    rows = []
    for img in images:
        coeffs = pywt.wavedec2(img, wavelet=wavelet, level=level)
        # coeffs[0]  = LL (approximation at deepest level)
        # coeffs[k]  = (LH, HL, HH) for scale k
        feats = _band_stats(coeffs[0])          # LL approximation
        for detail_tuple in coeffs[1:]:         # detail coefficients
            for band in detail_tuple:           # LH, HL, HH
                feats.extend(_band_stats(band))
        rows.append(np.array(feats, np.float32))
    return np.array(rows, dtype=np.float32)


print("Feature extractors defined.")
print(f"  GLCM output size  : 6 properties (always)")
print(f"  LBP  output size  : P+2 or 2^P depending on method")
print(f"  DWT  output size  : 4*(3*level+1) features")
print(f"    e.g. level=1 → {4*(3*1+1)} features")
print(f"    e.g. level=2 → {4*(3*2+1)} features")
print(f"    e.g. level=3 → {4*(3*3+1)} features")

# %%
# ═══════════════════════════════════════════════════════════════════════════
# Phase 1 bundle I/O — fingerprint, skip scans, save for Phase 2, run history
# ═══════════════════════════════════════════════════════════════════════════
import json
from datetime import datetime, timezone


def phase1_input_fingerprint():
    """Hash of dataset preprocessing tag + all four parameter grids."""
    key = "|".join(
        (
            cache_tag,
            repr(GLCM_GRID),
            repr(LBP_GRID),
            repr(DWT_GRID),
            repr(HOG_GRID),
        )
    )
    return hashlib.md5(key.encode("utf-8")).hexdigest()


def phase1_bundle_best_params():
    return {
        "GLCM": {
            "distances": BEST_GLCM_DIST,
            "angles": np.asarray(BEST_GLCM_ANG, dtype=float).tolist(),
            "levels": int(BEST_GLCM_LVL),
            "symmetric": bool(BEST_GLCM_SYM),
        },
        "LBP": {
            "P": int(BEST_LBP_P),
            "R": int(BEST_LBP_R),
            "method": str(BEST_LBP_METHOD),
        },
        "DWT": {"wavelet": str(BEST_DWT_WAV), "level": int(BEST_DWT_LEVEL)},
        "HOG": {
            "orientations": int(BEST_HOG_ORI),
            "pixels_per_cell": tuple(BEST_HOG_PPC),
            "cells_per_block": tuple(BEST_HOG_CPB),
            "block_norm": str(BEST_HOG_NORM),
        },
    }


def phase1_outcome_hash(best, scores):
    """Digest of selected hyperparameters + top-row scores; stable across reruns with fixed SEED."""
    blob = json.dumps({"best": best, "scores": scores}, sort_keys=True, default=str)
    return hashlib.md5(blob.encode("utf-8")).hexdigest()


def _last_manifest_outcome_hash():
    if not PHASE1_MANIFEST_PATH.exists():
        return None
    try:
        mf = pd.read_csv(PHASE1_MANIFEST_PATH)
        if mf.empty or "outcome_hash" not in mf.columns:
            return None
        return str(mf.iloc[-1]["outcome_hash"])
    except Exception:
        return None


def _append_search_table(name, df, run_id, fp, oh, ts):
    path = PHASE1_FULL_SEARCH_DIR / f"{name}_history.csv"
    out = df.copy()
    out.insert(0, "saved_at_utc", ts)
    out.insert(0, "outcome_hash", oh)
    out.insert(0, "input_fingerprint", fp)
    out.insert(0, "phase1_run_id", run_id)
    out.to_csv(path, mode="a", header=not path.exists(), index=False)


def append_phase1_search_archives(bundle, run_id, fp, oh, ts):
    if not PHASE1_APPEND_FULL_SEARCH_HISTORY:
        return
    _append_search_table("glcm", bundle["glcm_df"], run_id, fp, oh, ts)
    _append_search_table("lbp", bundle["lbp_df"], run_id, fp, oh, ts)
    _append_search_table("dwt", bundle["dwt_df"], run_id, fp, oh, ts)
    _append_search_table("hog", bundle["hog_df"], run_id, fp, oh, ts)
    print(f"Appended scan tables under: {PHASE1_FULL_SEARCH_DIR}")


def append_phase1_manifest_row(bundle, run_id, oh, ts):
    row = {
        "timestamp_utc": ts,
        "phase1_run_id": run_id,
        "fingerprint": bundle["fingerprint"],
        "outcome_hash": oh,
        "cache_tag": bundle["cache_tag"],
        "score_glcm": bundle["scores"]["glcm"],
        "score_lbp": bundle["scores"]["lbp"],
        "score_dwt": bundle["scores"]["dwt"],
        "score_hog": bundle["scores"]["hog"],
        "best_json": json.dumps(bundle["best"], sort_keys=True, default=str),
    }
    pd.DataFrame([row]).to_csv(
        PHASE1_MANIFEST_PATH,
        mode="a",
        header=not PHASE1_MANIFEST_PATH.exists(),
        index=False,
    )
    print(f"Recorded Phase 1 manifest row: {PHASE1_MANIFEST_PATH}")


def apply_phase1_bundle_payload(b):
    """Restore Phase 1 artefacts from a bundle dict."""
    g = globals()
    g["glcm_df"] = b["glcm_df"]
    g["lbp_df"] = b["lbp_df"]
    g["dwt_df"] = b["dwt_df"]
    g["hog_df"] = b["hog_df"]
    if b.get("class_names") is not None:
        g["class_names"] = list(b["class_names"])
    G = b["best"]["GLCM"]
    g["BEST_GLCM_DIST"] = G["distances"]
    g["BEST_GLCM_ANG"] = G["angles"]
    g["BEST_GLCM_LVL"] = int(G["levels"])
    g["BEST_GLCM_SYM"] = bool(G["symmetric"])
    L = b["best"]["LBP"]
    g["BEST_LBP_P"] = int(L["P"])
    g["BEST_LBP_R"] = int(L["R"])
    g["BEST_LBP_METHOD"] = str(L["method"])
    D = b["best"]["DWT"]
    g["BEST_DWT_WAV"] = str(D["wavelet"])
    g["BEST_DWT_LEVEL"] = int(D["level"])
    H = b["best"]["HOG"]
    g["BEST_HOG_ORI"] = int(H["orientations"])
    g["BEST_HOG_PPC"] = tuple(H["pixels_per_cell"])
    g["BEST_HOG_CPB"] = tuple(H["cells_per_block"])
    g["BEST_HOG_NORM"] = str(H["block_norm"])


def append_phase1_history(bundle):
    oh = bundle.get("outcome_hash", "")
    if PHASE1_SKIP_DUPLICATE_HISTORY_ROWS and PHASE1_HISTORY_PATH.exists() and oh:
        try:
            prev = pd.read_csv(PHASE1_HISTORY_PATH)
            if len(prev) and "outcome_hash" in prev.columns and oh in prev["outcome_hash"].astype(str).values:
                print("Phase 1 run history: outcome_hash already present — skip row append.")
                return
        except Exception:
            pass
    row = {
        "timestamp_utc": bundle["saved_at_utc"],
        "phase1_run_id": bundle.get("run_id", ""),
        "fingerprint": bundle["fingerprint"],
        "outcome_hash": bundle.get("outcome_hash", ""),
        "cache_tag": bundle["cache_tag"],
        "score_glcm": bundle["scores"]["glcm"],
        "score_lbp": bundle["scores"]["lbp"],
        "score_dwt": bundle["scores"]["dwt"],
        "score_hog": bundle["scores"]["hog"],
    }
    pd.DataFrame([row]).to_csv(
        PHASE1_HISTORY_PATH,
        mode="a",
        header=not PHASE1_HISTORY_PATH.exists(),
        index=False,
    )
    print(f"Appended Phase 1 run to history: {PHASE1_HISTORY_PATH}")


def save_phase1_bundle():
    """Persist full Phase 1 state for a separate Phase 2 session."""
    best = phase1_bundle_best_params()
    fp = phase1_input_fingerprint()
    scores = {
        "glcm": float(glcm_df.iloc[0]["score"]),
        "lbp": float(lbp_df.iloc[0]["score"]),
        "dwt": float(dwt_df.iloc[0]["score"]),
        "hog": float(hog_df.iloc[0]["score"]),
    }
    oh = phase1_outcome_hash(best, scores)
    if PHASE1_SKIP_IF_OUTCOME_UNCHANGED and _last_manifest_outcome_hash() == oh:
        print(
            "Phase 1 persistence skipped: outcome_hash matches last manifest row "
            "(same best hyperparameters and composite scores)."
        )
        return

    ts = datetime.now(timezone.utc).isoformat()
    run_id = datetime.now(timezone.utc).strftime("%Y%m%dT%H%M%S") + "_" + oh[:8]
    bundle = {
        "version": 2,
        "saved_at_utc": ts,
        "run_id": run_id,
        "fingerprint": fp,
        "outcome_hash": oh,
        "cache_tag": cache_tag,
        "class_names": list(class_names),
        "best": best,
        "glcm_df": glcm_df,
        "lbp_df": lbp_df,
        "dwt_df": dwt_df,
        "hog_df": hog_df,
        "scores": scores,
    }
    joblib.dump(bundle, PHASE1_BUNDLE_PATH)
    print(f"Saved Phase 1 bundle for Phase 2: {PHASE1_BUNDLE_PATH}")

    handoff = {
        "phase1_run_id": run_id,
        "saved_at_utc": ts,
        "fingerprint": fp,
        "outcome_hash": oh,
        "cache_tag": cache_tag,
        "class_names": list(class_names),
        "best": best,
        "scores": scores,
        "bundle_path": str(PHASE1_BUNDLE_PATH.resolve()),
    }
    PHASE1_BEST_JSON_PATH.write_text(json.dumps(handoff, indent=2, default=str), encoding="utf-8")
    print(f"Wrote handoff JSON: {PHASE1_BEST_JSON_PATH}")

    append_phase1_manifest_row(bundle, run_id, oh, ts)
    append_phase1_history(bundle)
    append_phase1_search_archives(bundle, run_id, fp, oh, ts)


def load_phase1_bundle_for_phase2():
    """After kernel restart: run imports → config → dataset → extractors, then this."""
    if not PHASE1_BUNDLE_PATH.exists():
        raise FileNotFoundError(
            f"Missing Phase 1 bundle ({PHASE1_BUNDLE_PATH}). Run Phase 1 once or copy the bundle file."
        )
    b = joblib.load(PHASE1_BUNDLE_PATH)
    apply_phase1_bundle_payload(b)
    print(f"Loaded Phase 1 bundle (saved {b.get('saved_at_utc', '?')}, fp={str(b.get('fingerprint', ''))[:12]}…).")


RUN_PHASE1_SCANS = True



def _phase1_scan_fingerprint(name, grid):
    key = f"{name}|{cache_tag}|{repr(grid)}"
    return hashlib.md5(key.encode("utf-8")).hexdigest()[:16]


def _phase1_scan_cache_path(name, grid):
    fp = _phase1_scan_fingerprint(name, grid)
    return PHASE1_SCAN_CACHE_DIR / f"{name}_{fp}.joblib"


def load_phase1_scan(name, grid):
    """Return cached scan payload or None."""
    if not USE_PHASE1_SCAN_CACHE or FORCE_PHASE1_RESCAN:
        return None
    path = _phase1_scan_cache_path(name, grid)
    if not path.exists():
        return None
    try:
        payload = joblib.load(path)
    except Exception as exc:
        print(f"  WARN: could not load {name} scan cache ({exc})")
        return None
    expected = _phase1_scan_fingerprint(name, grid)
    if payload.get("fingerprint") != expected:
        return None
    print(f"Loaded {name.upper()} scan from cache: {path.name} (saved {payload.get('saved_at_utc', '?')})")
    return payload


def save_phase1_scan(name, grid, df):
    """Persist one feature grid-search result table."""
    if not USE_PHASE1_SCAN_CACHE:
        return
    fp = _phase1_scan_fingerprint(name, grid)
    payload = {
        "version": 1,
        "name": name,
        "fingerprint": fp,
        "cache_tag": cache_tag,
        "grid": grid,
        "df": df,
        "saved_at_utc": datetime.now(timezone.utc).isoformat(),
    }
    path = _phase1_scan_cache_path(name, grid)
    joblib.dump(payload, path)
    print(f"Saved {name.upper()} scan cache: {path}")


def _apply_glcm_best_from_df():
    from ast import literal_eval
    best = glcm_df.iloc[0]
    g = globals()
    g["BEST_GLCM_DIST"] = literal_eval(best["distances"])
    g["BEST_GLCM_ANG"] = literal_eval(best["angles"])
    g["BEST_GLCM_LVL"] = int(best["levels"])
    g["BEST_GLCM_SYM"] = bool(best["symmetric"])


def _apply_lbp_best_from_df():
    best = lbp_df.iloc[0]
    g = globals()
    g["BEST_LBP_P"] = int(best["P"])
    g["BEST_LBP_R"] = int(best["R"])
    g["BEST_LBP_METHOD"] = str(best["method"])


def _apply_dwt_best_from_df():
    best = dwt_df.iloc[0]
    g = globals()
    g["BEST_DWT_WAV"] = str(best["wavelet"])
    g["BEST_DWT_LEVEL"] = int(best["level"])


def _apply_hog_best_from_df():
    from ast import literal_eval
    best = hog_df.iloc[0]
    g = globals()
    g["BEST_HOG_ORI"] = int(best["orientations"])
    g["BEST_HOG_PPC"] = literal_eval(best["pixels_per_cell"])
    g["BEST_HOG_CPB"] = literal_eval(best["cells_per_block"])
    g["BEST_HOG_NORM"] = str(best["block_norm"])


def try_skip_phase1_scans_from_per_scan_caches():
    """If every scan cache exists, restore all dfs and skip grid searches."""
    global RUN_PHASE1_SCANS
    if LOAD_PHASE1_BUNDLE_FOR_PHASE2 or FORCE_PHASE1_RESCAN or not USE_PHASE1_SCAN_CACHE:
        return False
    grids = [
        ("glcm", GLCM_GRID),
        ("lbp", LBP_GRID),
        ("dwt", DWT_GRID),
        ("hog", HOG_GRID),
    ]
    payloads = []
    for name, grid in grids:
        p = load_phase1_scan(name, grid)
        if p is None:
            return False
        payloads.append(p)
    g = globals()
    for name, p in zip(["glcm", "lbp", "dwt", "hog"], payloads):
        g[f"{name}_df"] = p["df"]
    _apply_glcm_best_from_df()
    _apply_lbp_best_from_df()
    _apply_dwt_best_from_df()
    _apply_hog_best_from_df()
    RUN_PHASE1_SCANS = False
    print("Phase 1 scans skipped — all four per-scan caches match current dataset + grids.")
    return True


def try_skip_phase1_scans_from_bundle():
    global RUN_PHASE1_SCANS
    if LOAD_PHASE1_BUNDLE_FOR_PHASE2:
        return
    if not SKIP_PHASE1_SCANS_IF_BUNDLE_MATCHES:
        return
    if not PHASE1_BUNDLE_PATH.exists():
        return
    try:
        b = joblib.load(PHASE1_BUNDLE_PATH)
    except Exception:
        return
    if b.get("fingerprint") != phase1_input_fingerprint():
        return
    apply_phase1_bundle_payload(b)
    RUN_PHASE1_SCANS = False
    print("Phase 1 scans skipped — bundle matches current dataset tag + parameter grids.")


if LOAD_PHASE1_BUNDLE_FOR_PHASE2:
    load_phase1_bundle_for_phase2()
    RUN_PHASE1_SCANS = False
elif not try_skip_phase1_scans_from_per_scan_caches():
    try_skip_phase1_scans_from_bundle()

# %% [markdown]
# ### 6. Phase 1A — GLCM Parameter Selection

# %%
from ast import literal_eval

def _print_glcm_best(header):
    print(header)
    print(f"  distances : {BEST_GLCM_DIST}")
    print(f"  angles    : {BEST_GLCM_ANG}")
    print(f"  levels    : {BEST_GLCM_LVL}")
    print(f"  symmetric : {BEST_GLCM_SYM}")
    print(f"  score     : {glcm_df.iloc[0]['score']:.4f}")

_glcm_cache = load_phase1_scan("glcm", GLCM_GRID)
if _glcm_cache is not None:
    glcm_df = _glcm_cache["df"]
    _apply_glcm_best_from_df()
    _print_glcm_best("\n✓ Best GLCM config (from cache):")
elif RUN_PHASE1_SCANS:
    print("Scanning GLCM parameter space …")
    glcm_rows = []

    configs = list(itertools.product(
        GLCM_GRID["distances"],
        GLCM_GRID["angles"],
        GLCM_GRID["levels"],
        GLCM_GRID["symmetric"],
    ))
    print(f"Total GLCM configurations: {len(configs)}")

    for dist, ang, lvl, sym in tqdm(configs, desc="GLCM"):
        label = (f"d={dist} a={len(ang)}ang "
                 f"l={lvl} sym={sym}")
        try:
            X_feat = extract_glcm(X_train_raw, dist, ang, lvl, sym)
            metrics = evaluate_features(X_feat, y_train)
            glcm_rows.append({
                "distances":  str(dist),
                "n_distances": len(dist),
                "angles":     str([round(a,3) for a in ang]),
                "n_angles":   len(ang),
                "levels":     lvl,
                "symmetric":  sym,
                "n_features": X_feat.shape[1],
                "label":      label,
                **metrics,
            })
        except Exception as e:
            print(f"  SKIP {label}: {e}")

    glcm_df = pd.DataFrame(glcm_rows)

    mms = MinMaxScaler()
    glcm_df["FDR_n"]  = mms.fit_transform(glcm_df[["FDR"]])
    glcm_df["MI_n"]   = mms.fit_transform(glcm_df[["MI"]])
    glcm_df["DBI_n"]  = 1 - mms.fit_transform(glcm_df[["DBI"]])
    glcm_df["score"]  = (glcm_df["FDR_n"] + glcm_df["MI_n"] + glcm_df["DBI_n"]) / 3
    glcm_df = glcm_df.sort_values("score", ascending=False).reset_index(drop=True)

    print("\nTop 10 GLCM configurations:")
    display(glcm_df[["distances","n_angles","levels","symmetric",
                     "n_features","FDR","MI","DBI","score"]].head(10).round(4))

    _apply_glcm_best_from_df()
    _print_glcm_best("\n✓ Best GLCM config:")
    save_phase1_scan("glcm", GLCM_GRID, glcm_df)
else:
    _print_glcm_best("\n✓ Best GLCM config (restored from bundle):")

GLCM_PROPS = ["contrast", "dissimilarity", "homogeneity", "energy", "correlation", "ASM"]

def glcm_features_for_one_image(img, distances, angles, levels, symmetric):
    q = np.clip(np.floor(img * levels), 0, levels - 1).astype(np.uint8)
    glcm = graycomatrix(
        q,
        distances=distances,
        angles=angles,
        levels=levels,
        symmetric=symmetric,
        normed=True,
    )
    return np.array([graycoprops(glcm, p).mean() for p in GLCM_PROPS], dtype=np.float32)

if RUN_PHASE1_VIZ:
    def plot_glcm_features_on_image(img, distances, angles, levels, symmetric, title_suffix=""):
        vals = glcm_features_for_one_image(img, distances, angles, levels, symmetric)
        fig, axes = plt.subplots(1, 2, figsize=(12, 4))
        axes[0].imshow(img, cmap="gray")
        axes[0].set_title("Input image")
        axes[0].axis("off")
        axes[1].bar(GLCM_PROPS, vals, color="tab:blue", alpha=0.85)
        axes[1].set_title("GLCM features" + (f"\n{title_suffix}" if title_suffix else ""))
        axes[1].set_ylabel("Value")
        axes[1].tick_params(axis="x", rotation=30)
        plt.tight_layout()
        plt.show()

    sample_idx = 0
    sample_img = X_train_raw[sample_idx]
    glcm_to_plot = glcm_df.head(10)
    for _, row in glcm_to_plot.iterrows():
        dist = literal_eval(row["distances"])
        ang  = literal_eval(row["angles"])
        lvl  = int(row["levels"])
        sym  = bool(row["symmetric"])
        label = f"d={dist}, a={ang}, levels={lvl}, sym={sym}"
        plot_glcm_features_on_image(sample_img, dist, ang, lvl, sym, title_suffix=label)

# %%
# ── GLCM visualisation ─────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle("GLCM Parameter Search — Separability Metrics", fontsize=14, fontweight="bold")

metrics_plot = [("FDR","Fisher Discriminant Ratio (↑ better)","Blues"),
                ("MI", "Mutual Information (↑ better)",       "Greens"),
                ("DBI","Davies-Bouldin Index (↓ better)",     "Reds")]

for ax, (met, title, cmap) in zip(axes, metrics_plot):
    # Pivot: group by n_distances vs n_angles, average over levels & symmetric
    piv = glcm_df.groupby(["n_distances","n_angles"])[met].mean().unstack()
    if met == "DBI":
        # For DBI invert colour (lower=better should be dark)
        sns.heatmap(piv, ax=ax, cmap=cmap+"_r", annot=True, fmt=".3f",
                    linewidths=0.5, cbar_kws={"label": met})
    else:
        sns.heatmap(piv, ax=ax, cmap=cmap, annot=True, fmt=".3f",
                    linewidths=0.5, cbar_kws={"label": met})
    ax.set_title(title, fontsize=11)
    ax.set_xlabel("Number of angles")
    ax.set_ylabel("Number of distances")

plt.tight_layout()
plt.savefig(OUTPUT_DIR / "glcm_param_search.png", dpi=120, bbox_inches="tight")
plt.show()

# ── Score bar chart: top 15 configs ───────────────────────────────────────
fig, ax = plt.subplots(figsize=(14, 6))
top15 = glcm_df.head(15)
bars = ax.barh(range(15)[::-1], top15["score"],
               color=sns.color_palette("Blues_r", 15))
ax.set_yticks(range(15)[::-1])
ax.set_yticklabels(top15["label"], fontsize=8)
ax.set_xlabel("Composite separability score (0–1)")
ax.set_title("Top 15 GLCM Configurations", fontsize=13, fontweight="bold")
ax.bar_label(bars, fmt="%.4f", fontsize=8, padding=2)
ax.axvline(top15["score"].max(), color="red", ls="--", lw=1, alpha=0.6)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "glcm_top15.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: glcm_param_search.png, glcm_top15.png")

# %% [markdown]
# ### 7. Phase 1B — LBP Parameter Selection

# %%
_lbp_cache = load_phase1_scan("lbp", LBP_GRID)
if _lbp_cache is not None:
    lbp_df = _lbp_cache["df"]
    _apply_lbp_best_from_df()
    print("\n✓ Best LBP config (from cache):")
    print(f"  P      : {BEST_LBP_P}")
    print(f"  R      : {BEST_LBP_R}")
    print(f"  method : {BEST_LBP_METHOD}")
    print(f"  score  : {lbp_df.iloc[0]['score']:.4f}")
elif RUN_PHASE1_SCANS:
    print("Scanning LBP parameter space …")
    lbp_rows = []

    configs_lbp = list(itertools.product(
        LBP_GRID["P"],
        LBP_GRID["R"],
        LBP_GRID["method"],
    ))
    print(f"Total LBP configurations: {len(configs_lbp)}")

    for P, R, method in tqdm(configs_lbp, desc="LBP"):
        label = f"P={P:2d} R={R} method={method}"
        try:
            X_feat = extract_lbp(X_train_raw, P, R, method)
            metrics = evaluate_features(X_feat, y_train)
            lbp_rows.append({
                "P": P, "R": R, "method": method,
                "n_features": X_feat.shape[1],
                "label": label,
                **metrics,
            })
        except Exception as e:
            print(f"  SKIP {label}: {e}")

    lbp_df = pd.DataFrame(lbp_rows)

    mms = MinMaxScaler()
    lbp_df["FDR_n"] = mms.fit_transform(lbp_df[["FDR"]])
    lbp_df["MI_n"]  = mms.fit_transform(lbp_df[["MI"]])
    lbp_df["DBI_n"] = 1 - mms.fit_transform(lbp_df[["DBI"]])
    lbp_df["score"] = (lbp_df["FDR_n"] + lbp_df["MI_n"] + lbp_df["DBI_n"]) / 3
    lbp_df = lbp_df.sort_values("score", ascending=False).reset_index(drop=True)

    print("\nTop 10 LBP configurations:")
    display(lbp_df[["P","R","method","n_features","FDR","MI","DBI","score"]].head(10).round(4))

    _apply_lbp_best_from_df()
    print(f"\n✓ Best LBP config:")
    print(f"  P      : {BEST_LBP_P}")
    print(f"  R      : {BEST_LBP_R}")
    print(f"  method : {BEST_LBP_METHOD}")
    print(f"  score  : {lbp_df.iloc[0]['score']:.4f}")
    save_phase1_scan("lbp", LBP_GRID, lbp_df)
else:
    print("LBP scans skipped — using Phase 1 bundle.")
    print(f"\n✓ Best LBP config (restored):")
    print(f"  P      : {BEST_LBP_P}")
    print(f"  R      : {BEST_LBP_R}")
    print(f"  method : {BEST_LBP_METHOD}")
    print(f"  score  : {lbp_df.iloc[0]['score']:.4f}")

def lbp_features_for_one_image(img, P, R, method):
    lbp = local_binary_pattern(img, P=P, R=R, method=method)
    MAX_LBP_BINS = 4096
    if method in ("uniform", "nri_uniform"):
        n_bins = P + 2
        hist_range = (0, n_bins)
    else:
        full_bins = 2 ** P
        n_bins = min(full_bins, MAX_LBP_BINS)
        hist_range = (0, full_bins)
    hist, _ = np.histogram(lbp.ravel(), bins=n_bins, range=hist_range, density=True)
    return lbp, hist.astype(np.float32)

if RUN_PHASE1_VIZ:
    def plot_lbp_features_on_image(img, P, R, method, title_suffix=""):
        lbp_img, hist = lbp_features_for_one_image(img, P, R, method)
        fig, axes = plt.subplots(1, 3, figsize=(16, 4.5))
        axes[0].imshow(img, cmap="gray")
        axes[0].set_title("Input image")
        axes[0].axis("off")
        axes[1].imshow(lbp_img, cmap="magma")
        axes[1].set_title(f"LBP map ({method})")
        axes[1].axis("off")
        axes[2].bar(np.arange(len(hist)), hist, color="tab:orange", alpha=0.9)
        axes[2].set_title("LBP feature histogram" + (f"\n{title_suffix}" if title_suffix else ""))
        axes[2].set_xlabel("LBP bin index")
        axes[2].set_ylabel("Density")
        plt.tight_layout()
        plt.show()

    sample_idx = 0
    sample_img = X_train_raw[sample_idx]
    lbp_to_plot = lbp_df.head(10)
    for _, row in lbp_to_plot.iterrows():
        P = int(row["P"])
        R = int(row["R"])
        method = str(row["method"])
        label = f"P={P}, R={R}, method={method}"
        plot_lbp_features_on_image(sample_img, P, R, method, title_suffix=label)

# %%
# ── LBP visualisation ─────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle("LBP Parameter Search — Separability Metrics", fontsize=14, fontweight="bold")

for ax, (met, title, cmap) in zip(axes, [
        ("FDR","Fisher Discriminant Ratio (↑ better)","Blues"),
        ("MI", "Mutual Information (↑ better)",       "Greens"),
        ("DBI","Davies-Bouldin Index (↓ better)",     "Reds")]):

    piv = lbp_df.groupby(["P","R"])[met].mean().unstack()
    inv = (met == "DBI")
    sns.heatmap(piv, ax=ax, cmap=cmap+"_r" if inv else cmap,
                annot=True, fmt=".3f", linewidths=0.5,
                cbar_kws={"label": met})
    ax.set_title(title, fontsize=11)
    ax.set_xlabel("R (radius)")
    ax.set_ylabel("P (sampling points)")

plt.tight_layout()
plt.savefig(OUTPUT_DIR / "lbp_param_search.png", dpi=120, bbox_inches="tight")
plt.show()

# ── Score by method ────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, len(LBP_GRID["method"]), figsize=(18, 5), sharey=False)
fig.suptitle("LBP Score by Method", fontsize=13, fontweight="bold")
method_colors = sns.color_palette("Set2", len(LBP_GRID["method"]))

for ax, (method, color) in zip(axes, zip(LBP_GRID["method"], method_colors)):
    sub = lbp_df[lbp_df["method"]==method].sort_values("score", ascending=False)
    bars = ax.bar(range(len(sub)), sub["score"], color=color, edgecolor="white")
    ax.set_xticks(range(len(sub)))
    ax.set_xticklabels([f"P={r['P']},R={r['R']}" for _, r in sub.iterrows()],
                       rotation=40, ha="right", fontsize=8)
    ax.set_title(f"method = {method}", fontsize=11)
    ax.set_ylim(0, 1)
    ax.set_ylabel("Composite score")
    ax.bar_label(bars, fmt="%.3f", fontsize=7, padding=1)

plt.tight_layout()
plt.savefig(OUTPUT_DIR / "lbp_by_method.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: lbp_param_search.png, lbp_by_method.png")

# ── Optional compact view: top-LBP configs vs feature bins (sample image) ──
sample_idx = 0
sample_img = X_train_raw[sample_idx]
lbp_top = lbp_df.head(10)

max_bins = int(lbp_top["n_features"].max())
feature_matrix = np.full((len(lbp_top), max_bins), np.nan, dtype=np.float32)
row_labels = []

for i, (_, row) in enumerate(lbp_top.iterrows()):
    P = int(row["P"])
    R = int(row["R"])
    method = str(row["method"])
    _, hist = lbp_features_for_one_image(sample_img, P, R, method)
    feature_matrix[i, :len(hist)] = hist
    row_labels.append(f"P={P},R={R},{method}")

plt.figure(figsize=(14, 5))
sns.heatmap(feature_matrix, cmap="mako", cbar_kws={"label": "Density"})
plt.yticks(np.arange(len(row_labels)) + 0.5, row_labels, rotation=0)
plt.xlabel("LBP feature bin index")
plt.ylabel("Parameter configuration")
plt.title("LBP feature vectors on one image (top 10 configs)")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "lbp_feature_vectors_top10.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: lbp_feature_vectors_top10.png")

# %% [markdown]
# ### 8. Phase 1C — DWT Parameter Selection

# %%
_dwt_cache = load_phase1_scan("dwt", DWT_GRID)
if _dwt_cache is not None:
    dwt_df = _dwt_cache["df"]
    _apply_dwt_best_from_df()
    print("\n✓ Best DWT config (from cache):")
    print(f"  wavelet : {BEST_DWT_WAV}")
    print(f"  level   : {BEST_DWT_LEVEL}")
    print(f"  score   : {dwt_df.iloc[0]['score']:.4f}")
elif RUN_PHASE1_SCANS:
    print("Scanning DWT parameter space …")
    dwt_rows = []

    configs_dwt = list(itertools.product(DWT_GRID["wavelet"], DWT_GRID["level"]))
    print(f"Total DWT configurations: {len(configs_dwt)}")

    for wavelet, level in tqdm(configs_dwt, desc="DWT"):
        label = f"wavelet={wavelet:8s} level={level}"
        try:
            X_feat  = extract_dwt(X_train_raw, wavelet, level)
            metrics = evaluate_features(X_feat, y_train)
            dwt_rows.append({
                "wavelet":    wavelet,
                "level":      level,
                "n_features": X_feat.shape[1],
                "label":      label,
                **metrics,
            })
        except Exception as e:
            print(f"  SKIP {label}: {e}")

    dwt_df = pd.DataFrame(dwt_rows)

    mms = MinMaxScaler()
    dwt_df["FDR_n"] = mms.fit_transform(dwt_df[["FDR"]])
    dwt_df["MI_n"]  = mms.fit_transform(dwt_df[["MI"]])
    dwt_df["DBI_n"] = 1 - mms.fit_transform(dwt_df[["DBI"]])
    dwt_df["score"] = (dwt_df["FDR_n"] + dwt_df["MI_n"] + dwt_df["DBI_n"]) / 3
    dwt_df = dwt_df.sort_values("score", ascending=False).reset_index(drop=True)

    print("\nAll DWT configurations (sorted by score):")
    display(dwt_df[["wavelet","level","n_features","FDR","MI","DBI","score"]].round(4))

    _apply_dwt_best_from_df()
    print(f"\n✓ Best DWT config:")
    print(f"  wavelet : {BEST_DWT_WAV}")
    print(f"  level   : {BEST_DWT_LEVEL}")
    print(f"  score   : {dwt_df.iloc[0]['score']:.4f}")
    save_phase1_scan("dwt", DWT_GRID, dwt_df)
else:
    print("DWT scans skipped — using Phase 1 bundle.")
    print(f"\n✓ Best DWT config (restored):")
    print(f"  wavelet : {BEST_DWT_WAV}")
    print(f"  level   : {BEST_DWT_LEVEL}")
    print(f"  score   : {dwt_df.iloc[0]['score']:.4f}")

def dwt_features_for_one_image(img, wavelet, level):
    return extract_dwt([img], wavelet, level)[0].astype(np.float32)

if RUN_PHASE1_VIZ:
    def dwt_decompose_for_plot(img, wavelet, level):
        return pywt.wavedec2(img, wavelet=wavelet, level=level)

    def plot_dwt_features_on_image(img, wavelet, level, title_suffix=""):
        feat = dwt_features_for_one_image(img, wavelet, level)
        coeffs = dwt_decompose_for_plot(img, wavelet, level)
        fig, axes = plt.subplots(1, 3, figsize=(16, 4.5))
        axes[0].imshow(img, cmap="gray")
        axes[0].set_title("Input image")
        axes[0].axis("off")
        cA = coeffs[0]
        axes[1].imshow(cA, cmap="viridis")
        axes[1].set_title(f"Approximation cA (L{level})")
        axes[1].axis("off")
        axes[2].bar(np.arange(len(feat)), feat, color="tab:green", alpha=0.9)
        axes[2].set_title("DWT feature vector" + (f"\n{title_suffix}" if title_suffix else ""))
        axes[2].set_xlabel("Feature index")
        axes[2].set_ylabel("Value")
        plt.tight_layout()
        plt.show()

    sample_idx = 0
    sample_img = X_train_raw[sample_idx]
    dwt_to_plot = dwt_df.head(10)
    for _, row in dwt_to_plot.iterrows():
        wavelet = str(row["wavelet"])
        level = int(row["level"])
        label = f"wavelet={wavelet}, level={level}"
        plot_dwt_features_on_image(sample_img, wavelet, level, title_suffix=label)

# %%
# ── DWT visualisation ─────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle("DWT Parameter Search — Separability Metrics", fontsize=14, fontweight="bold")

for ax, (met, title, cmap) in zip(axes, [
        ("FDR","Fisher Discriminant Ratio (↑ better)","Blues"),
        ("MI", "Mutual Information (↑ better)",       "Greens"),
        ("DBI","Davies-Bouldin Index (↓ better)",     "Reds")]):

    piv = dwt_df.pivot(index="wavelet", columns="level", values=met)
    inv = (met == "DBI")
    sns.heatmap(piv, ax=ax, cmap=cmap+"_r" if inv else cmap,
                annot=True, fmt=".3f", linewidths=0.5,
                cbar_kws={"label": met})
    ax.set_title(title, fontsize=11)
    ax.set_xlabel("Decomposition level")
    ax.set_ylabel("Wavelet family")

plt.tight_layout()
plt.savefig(OUTPUT_DIR / "dwt_param_search.png", dpi=120, bbox_inches="tight")
plt.show()

# ── Score bar chart ────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(12, 5))
width = 0.25
wavelets = DWT_GRID["wavelet"]
levels   = DWT_GRID["level"]
lev_colors = sns.color_palette("muted", len(levels))
x = np.arange(len(wavelets))

for li, (lv, col) in enumerate(zip(levels, lev_colors)):
    vals = [dwt_df[(dwt_df.wavelet==wv)&(dwt_df.level==lv)]["score"].values[0]
            if len(dwt_df[(dwt_df.wavelet==wv)&(dwt_df.level==lv)])>0 else 0
            for wv in wavelets]
    bars = ax.bar(x + (li - len(levels)/2 + 0.5)*width, vals, width,
                  label=f"Level {lv}", color=col, edgecolor="white")
    ax.bar_label(bars, fmt="%.3f", fontsize=7, padding=1, rotation=90)

ax.set_xticks(x)
ax.set_xticklabels(wavelets, fontsize=10)
ax.set_ylabel("Composite separability score")
ax.set_title("DWT Score by Wavelet Family and Level", fontsize=13, fontweight="bold")
ax.legend(fontsize=10)
ax.set_ylim(0, 1.15)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "dwt_wavelet_comparison.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: dwt_param_search.png, dwt_wavelet_comparison.png")

# ── Optional compact view: top-DWT configs vs feature indices ─────────────
sample_idx = 0
sample_img = X_train_raw[sample_idx]
dwt_top = dwt_df.head(10)

max_features = int(dwt_top["n_features"].max())
feature_matrix = np.full((len(dwt_top), max_features), np.nan, dtype=np.float32)
row_labels = []

for i, (_, row) in enumerate(dwt_top.iterrows()):
    wavelet = str(row["wavelet"])
    level = int(row["level"])
    feat = dwt_features_for_one_image(sample_img, wavelet, level)
    feature_matrix[i, :len(feat)] = feat
    row_labels.append(f"{wavelet},L{level}")

plt.figure(figsize=(14, 5))
sns.heatmap(feature_matrix, cmap="crest", cbar_kws={"label": "Feature value"})
plt.yticks(np.arange(len(row_labels)) + 0.5, row_labels, rotation=0)
plt.xlabel("DWT feature index")
plt.ylabel("Parameter configuration")
plt.title("DWT feature vectors on one image (top 10 configs)")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "dwt_feature_vectors_top10.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: dwt_feature_vectors_top10.png")

# %% [markdown]
# ### 9. Phase 1D — HOG Parameter Selection

# %%
from ast import literal_eval

_hog_cache = load_phase1_scan("hog", HOG_GRID)
if _hog_cache is not None:
    hog_df = _hog_cache["df"]
    _apply_hog_best_from_df()
    print("\n✓ Best HOG config (from cache):")
    print(f"  orientations    : {BEST_HOG_ORI}")
    print(f"  pixels_per_cell : {BEST_HOG_PPC}")
    print(f"  cells_per_block : {BEST_HOG_CPB}")
    print(f"  block_norm      : {BEST_HOG_NORM}")
    print(f"  score           : {hog_df.iloc[0]['score']:.4f}")
elif RUN_PHASE1_SCANS:
    print("Scanning HOG parameter space …")
    hog_rows = []

    configs_hog = list(itertools.product(
        HOG_GRID["orientations"],
        HOG_GRID["pixels_per_cell"],
        HOG_GRID["cells_per_block"],
        HOG_GRID["block_norm"],
    ))
    print(f"Total HOG configurations: {len(configs_hog)}")

    def extract_hog(images, orientations, pixels_per_cell, cells_per_block, block_norm):
        rows = []
        for img in images:
            feat = hog(
                img,
                orientations=orientations,
                pixels_per_cell=pixels_per_cell,
                cells_per_block=cells_per_block,
                block_norm=block_norm,
                feature_vector=True,
            ).astype(np.float32)
            rows.append(feat)
        return np.vstack(rows).astype(np.float32)

    for orientations, ppc, cpb, block_norm in tqdm(configs_hog, desc="HOG"):
        label = f"ori={orientations} ppc={ppc} cpb={cpb} norm={block_norm}"
        try:
            X_feat = extract_hog(X_train_raw, orientations, ppc, cpb, block_norm)
            metrics = evaluate_features(X_feat, y_train)
            hog_rows.append({
                "orientations": orientations,
                "pixels_per_cell": str(ppc),
                "cells_per_block": str(cpb),
                "block_norm": block_norm,
                "n_features": X_feat.shape[1],
                "label": label,
                **metrics,
            })
        except Exception as e:
            print(f"  SKIP {label}: {e}")

    hog_df = pd.DataFrame(hog_rows)
    if hog_df.empty:
        raise RuntimeError("No valid HOG configuration was evaluated.")

    mms = MinMaxScaler()
    hog_df["FDR_n"] = mms.fit_transform(hog_df[["FDR"]])
    hog_df["MI_n"] = mms.fit_transform(hog_df[["MI"]])
    hog_df["DBI_n"] = 1 - mms.fit_transform(hog_df[["DBI"]])
    hog_df["score"] = (hog_df["FDR_n"] + hog_df["MI_n"] + hog_df["DBI_n"]) / 3
    hog_df = hog_df.sort_values("score", ascending=False).reset_index(drop=True)

    print("\nTop 10 HOG configurations:")
    display(hog_df[["orientations", "pixels_per_cell", "cells_per_block", "block_norm", "n_features", "FDR", "MI", "DBI", "score"]].head(10).round(4))

    _apply_hog_best_from_df()
    print(f"\n✓ Best HOG config:")
    print(f"  orientations    : {BEST_HOG_ORI}")
    print(f"  pixels_per_cell : {BEST_HOG_PPC}")
    print(f"  cells_per_block : {BEST_HOG_CPB}")
    print(f"  block_norm      : {BEST_HOG_NORM}")
    print(f"  score           : {hog_df.iloc[0]['score']:.4f}")
    save_phase1_scan("hog", HOG_GRID, hog_df)
else:
    print("HOG scans skipped — using Phase 1 bundle.")
    print(f"\n✓ Best HOG config (restored):")
    print(f"  orientations    : {BEST_HOG_ORI}")
    print(f"  pixels_per_cell : {BEST_HOG_PPC}")
    print(f"  cells_per_block : {BEST_HOG_CPB}")
    print(f"  block_norm      : {BEST_HOG_NORM}")
    print(f"  score           : {hog_df.iloc[0]['score']:.4f}")

def hog_features_for_one_image(img, orientations, pixels_per_cell, cells_per_block, block_norm):
    feat, hog_img = hog(
        img,
        orientations=orientations,
        pixels_per_cell=pixels_per_cell,
        cells_per_block=cells_per_block,
        block_norm=block_norm,
        visualize=True,
        feature_vector=True,
    )
    return feat.astype(np.float32), hog_img

if RUN_PHASE1_VIZ:
    def plot_hog_features_on_image(img, orientations, ppc, cpb, block_norm, title_suffix=""):
        feat, hog_img = hog_features_for_one_image(img, orientations, ppc, cpb, block_norm)
        fig, axes = plt.subplots(1, 3, figsize=(16, 4.5))
        axes[0].imshow(img, cmap="gray")
        axes[0].set_title("Input image")
        axes[0].axis("off")
        axes[1].imshow(hog_img, cmap="gray")
        axes[1].set_title("HOG visualisation")
        axes[1].axis("off")
        axes[2].plot(np.arange(len(feat)), feat, color="tab:purple", lw=1.0)
        axes[2].set_title("HOG feature vector" + (f"\n{title_suffix}" if title_suffix else ""))
        axes[2].set_xlabel("Feature index")
        axes[2].set_ylabel("Value")
        plt.tight_layout()
        plt.show()

    sample_idx = 0
    sample_img = X_train_raw[sample_idx]
    hog_to_plot = hog_df.head(10)
    for _, row in hog_to_plot.iterrows():
        ori = int(row["orientations"])
        ppc = literal_eval(row["pixels_per_cell"])
        cpb = literal_eval(row["cells_per_block"])
        norm = str(row["block_norm"])
        label = f"ori={ori}, ppc={ppc}, cpb={cpb}, norm={norm}"
        plot_hog_features_on_image(sample_img, ori, ppc, cpb, norm, title_suffix=label)

# %%
# ── HOG visualisation ─────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle("HOG Parameter Search — Separability Metrics", fontsize=14, fontweight="bold")

for ax, (met, title, cmap) in zip(axes, [
        ("FDR", "Fisher Discriminant Ratio (↑ better)", "Blues"),
        ("MI",  "Mutual Information (↑ better)",       "Greens"),
        ("DBI", "Davies-Bouldin Index (↓ better)",     "Reds")]):

    piv = hog_df.pivot_table(index="orientations", columns="pixels_per_cell", values=met, aggfunc="mean")
    inv = (met == "DBI")
    sns.heatmap(piv, ax=ax, cmap=cmap + "_r" if inv else cmap,
                annot=True, fmt=".3f", linewidths=0.5,
                cbar_kws={"label": met})
    ax.set_title(title, fontsize=11)
    ax.set_xlabel("pixels_per_cell")
    ax.set_ylabel("orientations")

plt.tight_layout()
plt.savefig(OUTPUT_DIR / "hog_param_search.png", dpi=120, bbox_inches="tight")
plt.show()

# ── Score by block/cell config ─────────────────────────────────────────────
hog_plot_df = hog_df.copy()
hog_plot_df["cfg"] = hog_plot_df.apply(
    lambda r: f"ori={int(r['orientations'])}\nppc={r['pixels_per_cell']}\ncpb={r['cells_per_block']}",
    axis=1,
)

plt.figure(figsize=(14, 5))
sub = hog_plot_df.sort_values("score", ascending=False).head(12)
bars = plt.bar(np.arange(len(sub)), sub["score"], color="tab:purple", edgecolor="white")
plt.xticks(np.arange(len(sub)), sub["cfg"], rotation=35, ha="right", fontsize=8)
plt.ylabel("Composite separability score")
plt.title("HOG Top Configurations by Score", fontsize=13, fontweight="bold")
plt.ylim(0, 1)
plt.bar_label(bars, fmt="%.3f", fontsize=7, padding=1)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "hog_top_configs.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: hog_param_search.png, hog_top_configs.png")

# %% [markdown]
# ### 10. Phase 1 Summary — Selected Parameters

# %%
print("=" * 65)
print("PHASE 1 COMPLETE — OPTIMAL FEATURE PARAMETERS SELECTED")
print("=" * 65)

print(f"\nGLCM:")
print(f"  distances  : {BEST_GLCM_DIST}")
print(f"  angles     : {[round(a,4) for a in BEST_GLCM_ANG]}")
print(f"  levels     : {BEST_GLCM_LVL}")
print(f"  symmetric  : {BEST_GLCM_SYM}")
print(f"  score      : {glcm_df.iloc[0]['score']:.4f}")

print(f"\nLBP:")
print(f"  P          : {BEST_LBP_P}")
print(f"  R          : {BEST_LBP_R}")
print(f"  method     : {BEST_LBP_METHOD}")
print(f"  score      : {lbp_df.iloc[0]['score']:.4f}")

print(f"\nDWT:")
print(f"  wavelet    : {BEST_DWT_WAV}")
print(f"  level      : {BEST_DWT_LEVEL}")
print(f"  score      : {dwt_df.iloc[0]['score']:.4f}")

print(f"\nHOG:")
print(f"  orientations    : {BEST_HOG_ORI}")
print(f"  pixels_per_cell : {BEST_HOG_PPC}")
print(f"  cells_per_block : {BEST_HOG_CPB}")
print(f"  block_norm      : {BEST_HOG_NORM}")
print(f"  score           : {hog_df.iloc[0]['score']:.4f}")

# ── Cross-feature comparison ───────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle("Best Config per Feature Type — Separability Comparison",
             fontsize=13, fontweight="bold")

feat_labels = ["GLCM", "LBP", "DWT", "HOG"]
feat_scores = [glcm_df.iloc[0], lbp_df.iloc[0], dwt_df.iloc[0], hog_df.iloc[0]]
met_names   = ["FDR", "MI", "DBI"]
met_titles  = ["Fisher DR (↑)", "Mutual Info (↑)", "Davies-Bouldin (↓)"]
colors      = sns.color_palette("Set2", 4)

for ax, (mname, mtitle) in zip(axes, zip(met_names, met_titles)):
    vals = [r[mname] for r in feat_scores]
    bars = ax.bar(feat_labels, vals, color=colors, edgecolor="white", linewidth=0.5)
    ax.set_title(mtitle, fontsize=11)
    ax.set_ylabel(mname)
    ax.bar_label(bars, fmt="%.4f", fontsize=10, padding=2)
    if mname == "DBI":
        # Add annotation: lower is better
        ax.annotate("↓ lower is better", xy=(0.5, 0.95),
                    xycoords="axes fraction", ha="center",
                    fontsize=9, color="gray")

plt.tight_layout()
plt.savefig(OUTPUT_DIR / "phase1_summary.png", dpi=120, bbox_inches="tight")
plt.show()

save_phase1_bundle()

# %% [markdown]
# ## 11. Phase 2 — Build Optimal Features & Run Model Benchmark
#
# Now that optimal parameters are selected we:
# 1. Extract features using best GLCM, LBP, DWT, and HOG parameters
# 2. Also compute first-order stats
# 3. Fuse all branches
# 4. Run GridSearchCV for SVM, KNN, RF
# 5. Produce a final performance dashboard

# %%
# Fresh kernel / Phase 2 only: set LOAD_PHASE1_BUNDLE_FOR_PHASE2 = True in config, then run
# imports → config → dataset → extractors → Phase 1 bundle cell before this one.
# Phase 1 also writes cache/brain_tumor/phase_artifacts/phase1_best.json and phase1_runs_manifest.csv.

print("Extracting features with OPTIMAL parameters …")

# ── First-order stats (no tunable params) ────────────────────────────────
def feat_stats(img):
    v = img.ravel()
    h, _ = np.histogram(v, bins=64, range=(0,1), density=True)
    h = (h+1e-12); h /= h.sum()
    ent = -(h*np.log2(h)).sum()
    p10,p25,p50,p75,p90 = np.percentile(v, [10,25,50,75,90])
    return np.array([v.mean(),v.std(),v.var(),ent,skew(v),kurtosis(v),
                     p10,p25,p50,p75,p90], np.float32)

def feat_hog(img):
    return hog(
        img,
        orientations=BEST_HOG_ORI,
        pixels_per_cell=tuple(BEST_HOG_PPC),
        cells_per_block=tuple(BEST_HOG_CPB),
        block_norm=BEST_HOG_NORM,
        feature_vector=True,
    ).astype(np.float32)

feature_cache_tag = (
    f"feat_glcm{BEST_GLCM_DIST}_{BEST_GLCM_ANG}_{BEST_GLCM_LVL}_{int(BEST_GLCM_SYM)}"
    f"_lbp{BEST_LBP_P}_{BEST_LBP_R}_{BEST_LBP_METHOD}_dwt{BEST_DWT_WAV}_{BEST_DWT_LEVEL}"
    f"_hog{BEST_HOG_ORI}_{tuple(BEST_HOG_PPC)}_{tuple(BEST_HOG_CPB)}_{BEST_HOG_NORM}"
)
feature_cache_hash = hashlib.md5(feature_cache_tag.encode("utf-8")).hexdigest()[:10]
feature_cache_path = CACHE_DIR / f"features_{feature_cache_hash}.npz"

if feature_cache_path.exists() and not FORCE_RECOMPUTE_CACHE:
    print(f"Loading features from cache: {feature_cache_path}")
    ft = np.load(feature_cache_path)
    A_tr, A_te = ft["A_tr"], ft["A_te"]
    B_glcm_tr, B_glcm_te = ft["B_glcm_tr"], ft["B_glcm_te"]
    B_lbp_tr, B_lbp_te = ft["B_lbp_tr"], ft["B_lbp_te"]
    B_tr, B_te = ft["B_tr"], ft["B_te"]
    C_tr, C_te = ft["C_tr"], ft["C_te"]
    D_tr, D_te = ft["D_tr"], ft["D_te"]
    FULL_tr, FULL_te = ft["FULL_tr"], ft["FULL_te"]
else:
    # ── Extract all branches ───────────────────────────────────────────────
    print("  Branch A: Stats …")
    A_tr = np.vstack([feat_stats(x) for x in tqdm(X_train_raw)])
    A_te = np.vstack([feat_stats(x) for x in tqdm(X_test_raw)])

    print("  Branch B: GLCM (optimal params) …")
    B_glcm_tr = extract_glcm(X_train_raw, BEST_GLCM_DIST, BEST_GLCM_ANG,
                             BEST_GLCM_LVL, BEST_GLCM_SYM)
    B_glcm_te = extract_glcm(X_test_raw,  BEST_GLCM_DIST, BEST_GLCM_ANG,
                             BEST_GLCM_LVL, BEST_GLCM_SYM)

    print("  Branch B: LBP (optimal params) …")
    B_lbp_tr = extract_lbp(X_train_raw, BEST_LBP_P, BEST_LBP_R, BEST_LBP_METHOD)
    B_lbp_te = extract_lbp(X_test_raw,  BEST_LBP_P, BEST_LBP_R, BEST_LBP_METHOD)

    # Combine GLCM + LBP into Branch B
    B_tr = np.hstack([B_glcm_tr, B_lbp_tr]).astype(np.float32)
    B_te = np.hstack([B_glcm_te, B_lbp_te]).astype(np.float32)

    print("  Branch C: DWT (optimal params) …")
    C_tr = extract_dwt(X_train_raw, BEST_DWT_WAV, BEST_DWT_LEVEL)
    C_te = extract_dwt(X_test_raw,  BEST_DWT_WAV, BEST_DWT_LEVEL)

    print("  Branch D: HOG …")
    D_tr = np.vstack([feat_hog(x) for x in tqdm(X_train_raw)])
    D_te = np.vstack([feat_hog(x) for x in tqdm(X_test_raw)])

    # Full fusion
    FULL_tr = np.hstack([A_tr, B_tr, C_tr, D_tr]).astype(np.float32)
    FULL_te = np.hstack([A_te, B_te, C_te, D_te]).astype(np.float32)

    np.savez_compressed(
        feature_cache_path,
        A_tr=A_tr, A_te=A_te,
        B_glcm_tr=B_glcm_tr, B_glcm_te=B_glcm_te,
        B_lbp_tr=B_lbp_tr, B_lbp_te=B_lbp_te,
        B_tr=B_tr, B_te=B_te,
        C_tr=C_tr, C_te=C_te,
        D_tr=D_tr, D_te=D_te,
        FULL_tr=FULL_tr, FULL_te=FULL_te,
    )
    print(f"Saved feature cache: {feature_cache_path}")

print(f"\nFeature sizes (train):")
print(f"  A (Stats)  : {A_tr.shape[1]}")
print(f"  B (Tex)    : {B_tr.shape[1]}  (GLCM={B_glcm_tr.shape[1]} + LBP={B_lbp_tr.shape[1]})")
print(f"  C (DWT)    : {C_tr.shape[1]}")
print(f"  D (HOG)    : {D_tr.shape[1]}")
print(f"  FULL fused : {FULL_tr.shape[1]}")

# ── Feature extraction plotting for each branch ──────────────────────────
def plot_feature_preview(ax, X, title, max_points=200):
    n_show = min(max_points, X.shape[1])
    ax.plot(X[0, :n_show], lw=1.2)
    ax.set_title(f"{title}\n(first sample, first {n_show} features)")
    ax.set_xlabel("Feature index")
    ax.set_ylabel("Value")

fig, axes = plt.subplots(2, 3, figsize=(16, 8))
plot_feature_preview(axes[0, 0], A_tr, "Branch A - Stats")
plot_feature_preview(axes[0, 1], B_glcm_tr, "Branch B1 - GLCM")
plot_feature_preview(axes[0, 2], B_lbp_tr, "Branch B2 - LBP")
plot_feature_preview(axes[1, 0], B_tr, "Branch B - Texture (GLCM+LBP)")
plot_feature_preview(axes[1, 1], C_tr, "Branch C - DWT")
plot_feature_preview(axes[1, 2], D_tr, "Branch D - HOG")
plt.tight_layout()
plt.show()

# Distribution summary by branch (mean +/- std)
branch_stats = pd.DataFrame({
    "Branch": ["A_Stats", "B_Texture", "C_DWT", "D_HOG", "FULL"],
    "n_features": [A_tr.shape[1], B_tr.shape[1], C_tr.shape[1], D_tr.shape[1], FULL_tr.shape[1]],
    "train_mean": [A_tr.mean(), B_tr.mean(), C_tr.mean(), D_tr.mean(), FULL_tr.mean()],
    "train_std": [A_tr.std(), B_tr.std(), C_tr.std(), D_tr.std(), FULL_tr.std()],
})

display(branch_stats)

# %%
# ── Cleaning pipeline ─────────────────────────────────────────────────────
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def clean_scale(Xtr, Xte, corr_thr=0.95):
    original_dim = Xtr.shape[1]

    # 1) Remove constant features
    vt = VarianceThreshold(0.0)
    Xtr_vt = vt.fit_transform(Xtr)
    Xte_vt = vt.transform(Xte)

    after_variance_dim = Xtr_vt.shape[1]

    # Track kept columns after variance filtering
    kept_after_variance = vt.get_support(indices=True)

    # 2) Remove highly correlated features
    kept_after_corr = np.arange(after_variance_dim)

    if Xtr_vt.shape[1] < 5000:
        corr = pd.DataFrame(Xtr_vt).corr().abs()
        upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))

        drop = [c for c in upper.columns if any(upper[c] > corr_thr)]

        if drop:
            keep = np.ones(Xtr_vt.shape[1], dtype=bool)
            keep[np.array(drop, int)] = False

            Xtr_vt = Xtr_vt[:, keep]
            Xte_vt = Xte_vt[:, keep]

            kept_after_corr = np.where(keep)[0]

    after_corr_dim = Xtr_vt.shape[1]

    # Final kept original feature indices
    final_kept_original_indices = kept_after_variance[kept_after_corr]

    # 3) Standardization
    sc = StandardScaler()
    Xtr_clean = sc.fit_transform(Xtr_vt)
    Xte_clean = sc.transform(Xte_vt)

    info = {
        "raw_dim": original_dim,
        "after_variance_dim": after_variance_dim,
        "after_corr_dim": after_corr_dim,
        "kept_indices": final_kept_original_indices,
        "removed_dim": original_dim - after_corr_dim,
        "kept_ratio": after_corr_dim / original_dim if original_dim > 0 else 0
    }

    return Xtr_clean, Xte_clean, info


# Feature sets to benchmark in Phase 2
OPT_SETS = {
    "A — Stats":       (A_tr, A_te),
    "B — Tex(opt)":    (B_tr, B_te),
    "C — DWT(opt)":    (C_tr, C_te),
    "D — HOG":         (D_tr, D_te),
    "A+B":             (np.hstack([A_tr, B_tr]), np.hstack([A_te, B_te])),
    "B+C(opt)":        (np.hstack([B_tr, C_tr]), np.hstack([B_te, C_te])),
    "A+B+C(opt)":      (np.hstack([A_tr, B_tr, C_tr]), np.hstack([A_te, B_te, C_te])),
    "Full(opt)":       (FULL_tr, FULL_te),
}

print("Cleaning feature sets …")

CLEAN_OPT = {}
CLEAN_INFO = {}

for name, (tr, te) in OPT_SETS.items():
    ct, ce, info = clean_scale(tr.astype(np.float32), te.astype(np.float32))

    CLEAN_OPT[name] = (ct, ce)
    CLEAN_INFO[name] = info

    print(
        f"  {name:18s}  "
        f"raw={info['raw_dim']:5d}  "
        f"after_var={info['after_variance_dim']:5d}  "
        f"cleaned={info['after_corr_dim']:5d}  "
        f"kept={info['kept_ratio']*100:6.2f}%"
    )


# ── Plot 1: Raw vs cleaned feature dimensions ─────────────────────────────
summary_df = pd.DataFrame([
    {
        "Feature Set": name,
        "Raw Features": info["raw_dim"],
        "After Variance Filter": info["after_variance_dim"],
        "Cleaned Features": info["after_corr_dim"],
        "Removed Features": info["removed_dim"],
        "Kept Ratio (%)": info["kept_ratio"] * 100
    }
    for name, info in CLEAN_INFO.items()
])

display(summary_df)

plt.figure(figsize=(13, 6))
x = np.arange(len(summary_df))
width = 0.25

plt.bar(x - width, summary_df["Raw Features"], width, label="Raw")
plt.bar(x, summary_df["After Variance Filter"], width, label="After variance filter")
plt.bar(x + width, summary_df["Cleaned Features"], width, label="Cleaned")

plt.xticks(x, summary_df["Feature Set"], rotation=35, ha="right")
plt.ylabel("Number of features")
plt.title("Raw vs cleaned feature dimensions")
plt.legend()
plt.tight_layout()
plt.show()


# ── Plot 2: Percentage of kept features ───────────────────────────────────
plt.figure(figsize=(12, 5))
plt.bar(summary_df["Feature Set"], summary_df["Kept Ratio (%)"])

plt.xticks(rotation=35, ha="right")
plt.ylabel("Kept features (%)")
plt.title("Percentage of features kept after cleaning")
plt.ylim(0, 105)
plt.tight_layout()
plt.show()


# ── Plot 3: Removed features count ────────────────────────────────────────
plt.figure(figsize=(12, 5))
plt.bar(summary_df["Feature Set"], summary_df["Removed Features"])

plt.xticks(rotation=35, ha="right")
plt.ylabel("Number of removed features")
plt.title("Number of removed features per feature set")
plt.tight_layout()
plt.show()

# %%
# ── Model benchmark grids (Phase 2) ───────────────────────────────────────
CV_FOLDS = 5
CV = StratifiedKFold(n_splits=CV_FOLDS, shuffle=True, random_state=SEED)

MODEL_GRIDS = {
    # SVM: test linear, polynomial, RBF, and sigmoid kernels
   "SVM": [
    {
        "kernel": ["linear"],
        "C": [
            0.001,
            0.01,
            0.1,
            1,
            10,
            100,
            1000
        ]
    },
    {
        "kernel": ["rbf"],
        "C": [
            0.001,
            0.01,
            0.1,
            1,
            10,
            100,
            1000
        ],
        "gamma": [
            "scale",
            "auto",
            1e-4,
            1e-3,
            1e-2,
            1e-1,
            1,
            10
        ]
    },
    {
        "kernel": ["poly"],
        "C": [
            0.001,
            0.01,
            0.1,
            1,
            10,
            100
        ],
        "gamma": [
            "scale",
            "auto",
            1e-4,
            1e-3,
            1e-2,
            1e-1,
            1
        ],
        "degree": [
            2,
            3,
            4,
            5
        ],
        "coef0": [
            0.0,
            0.1,
            0.5,
            1.0
        ]
    },
    {
        "kernel": ["sigmoid"],
        "C": [
            0.001,
            30.01,
            0.1,
            1,
            10,
            100
        ],
        "gamma": [
            "scale",
            "auto",
            1e-4,
            1e-3,
            1e-2,
            1e-1,
            1
        ],
        "coef0": [
            0.0,
            0.1,
            0.5,
            1.0
        ]
    },
],

    # KNN: test small and large neighborhoods, several distances, and weighting
    "KNN": {
        "n_neighbors": [1, 2, 3, 
        5, 7, 9, 11, 15, 21, 31, 41, 51
        ],
        "metric": ["euclidean", "manhattan", "chebyshev", "minkowski"],
        "weights": ["uniform", "distance"],
        "p": [1, 2, 3, 4
        ]
    },

    # Random Forest: test small, medium, and large forests with different tree constraints
    "RF": {
        "n_estimators": [50, 100, 200, 300, 500, 800, 1000
        ],
        "max_depth": [None, 5, 10, 20, 30, 50, 80
        ],
        "max_features": ["sqrt", "log2", None
        ],
        "min_samples_split": [2, 5, 10, 20
        ],
        "min_samples_leaf": [1, 2, 4, 8
        ],
        "bootstrap": [True, False
        ],
        "criterion": ["gini", "entropy", "log_loss"
        ],
    },
}

# %%
# ── Phase 2 benchmark (setup) ─────────────────────────────────────────────
# Run each model in its own cell below, then run the finalize cell to export metrics.
# Re-running this cell clears P2_ALL and P2 in memory; completed jobs stay on disk under
# phase2_benchmark/ (*.pkl + *.meta.json + *_cv_results.csv). Re-run a model cell to resume
# — finished (mode, feature_set) jobs load from cache; interrupted jobs restart that job only.
from sklearn.model_selection import StratifiedShuffleSplit, cross_val_predict
from pathlib import Path
from datetime import datetime, timezone
import json

MAX_EVAL_FOLDS = 10
# GridSearchCV.fit console verbosity (sklearn: 0=quiet, 1–3 more detail)
PHASE2_GS_VERBOSE = 2
EVAL_MODES = ["split"] + [f"cv_{k}" for k in range(1, MAX_EVAL_FOLDS + 1)]

ESTIMATORS = {
    "SVM": SVC(random_state=SEED, probability=True),
    "KNN": KNeighborsClassifier(),
    "RF":  RandomForestClassifier(random_state=SEED, n_jobs=-1),
}


def _sanitize_cv_results_df(df):
    """Convert extension dtypes (e.g. pandas StringDtype) to plain object for stable joblib round-trips."""
    if not isinstance(df, pd.DataFrame):
        return df
    out = df.copy()
    for col in out.columns:
        dt = out[col].dtype
        if not isinstance(dt, np.dtype):
            out[col] = out[col].astype(object)
    return out


def _sanitize_phase2_payload(payload):
    if not isinstance(payload, dict):
        return payload
    out = dict(payload)
    if "cv_results" in out:
        out["cv_results"] = _sanitize_cv_results_df(out["cv_results"])
    return out


def _safe_joblib_load(path):
    try:
        return joblib.load(path)
    except Exception as exc:
        print(f"  [RESUME] cache unreadable ({type(exc).__name__}: {exc}) — re-running …")
        return None

def _cv_for_mode(mode):
    if mode == "split":
        return CV
    if mode == "cv_1":
        # sklearn KFold/StratifiedKFold needs n_splits >= 2, so cv_1 uses one stratified shuffle split.
        return StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=SEED)
    if mode.startswith("cv_"):
        k = int(mode.split("_")[1])
        k = min(k, MAX_EVAL_FOLDS)  # enforce max folds
        return StratifiedKFold(n_splits=k, shuffle=True, random_state=SEED)
    raise ValueError(f"Unsupported mode: {mode}")


def _param_grid_size(grid):
    if isinstance(grid, dict):
        n = 1
        for v in grid.values():
            n *= len(v) if hasattr(v, "__len__") and not isinstance(v, str) else 1
        return int(n)
    if isinstance(grid, list):
        return sum(_param_grid_size(g) for g in grid)
    return 0


def run_grid(est, grid, Xtr, Xte, mode, mn, fs_name):
    cv_obj = _cv_for_mode(mode)
    n_cand = _param_grid_size(grid)
    print(f"    GridSearchCV: {n_cand} parameter settings × CV — this may take a while …")
    gs = GridSearchCV(
        est,
        grid,
        scoring="f1_macro",
        cv=cv_obj,
        n_jobs=-1,
        refit=True,
        return_train_score=False,
        verbose=PHASE2_GS_VERBOSE,
    )

    t0 = time.time()
    gs.fit(Xtr, y_train)
    fit_t = time.time() - t0
    print(f"    GridSearchCV done in {fit_t:.1f}s  |  best_cv={gs.best_score_:.4f}  |  best_params={gs.best_params_}")

    if mode == "split":
        t0 = time.time()
        yp = gs.best_estimator_.predict(Xte)
        pred_t = time.time() - t0
        y_eval = y_test
    elif mode == "cv_1":
        # cross_val_predict requires partition-style CV; StratifiedShuffleSplit is not one.
        # For cv_1, evaluate on its single held-out fold directly.
        tr_idx, te_idx = next(cv_obj.split(Xtr, y_train))
        est1 = gs.best_estimator_.__class__(**gs.best_estimator_.get_params())
        est1.fit(Xtr[tr_idx], y_train[tr_idx])
        t0 = time.time()
        yp = est1.predict(Xtr[te_idx])
        pred_t = time.time() - t0
        y_eval = y_train[te_idx]
    else:
        t0 = time.time()
        yp = cross_val_predict(gs.best_estimator_, Xtr, y_train, cv=cv_obj, n_jobs=-1)
        pred_t = time.time() - t0
        y_eval = y_train

    return {
        "eval_mode": mode,
        "best_params":   gs.best_params_,
        "best_cv":       gs.best_score_,
        "cv_results":    _sanitize_cv_results_df(pd.DataFrame(gs.cv_results_)),
        "y_pred":        yp,
        "acc":  accuracy_score(y_eval, yp),
        "f1m":  f1_score(y_eval, yp, average="macro",    zero_division=0),
        "f1w":  f1_score(y_eval, yp, average="weighted", zero_division=0),
        "prec": precision_score(y_eval, yp, average="macro", zero_division=0),
        "rec":  recall_score(y_eval, yp, average="macro",  zero_division=0),
        "fit_t": fit_t,
        "pred_t": pred_t,
        "estimator": gs.best_estimator_,
    }

# Cache per (mode, feature_set, model): safe to stop the notebook between jobs — re-run the same
# model cell; finished jobs reload from disk. Each job also writes *.meta.json + *_cv_results.csv.
phase2_cache_dir = PHASE_CACHE_DIR / "phase2_benchmark"
phase2_cache_dir.mkdir(parents=True, exist_ok=True)
PHASE2_MANIFEST_PATH = phase2_cache_dir / "phase2_checkpoint_manifest.json"


def _phase2_cache_file(mode, fs_name, model_name):
    tag = f"{mode}|{fs_name}|{model_name}|seed={SEED}|cv={CV_FOLDS}|n={len(y_train)}"
    h = hashlib.md5(tag.encode("utf-8")).hexdigest()[:12]
    return phase2_cache_dir / f"{h}.pkl"


def _atomic_joblib_dump(obj, path: Path):
    path = Path(path)
    tmp = path.with_suffix(path.suffix + ".tmp")
    joblib.dump(obj, tmp)
    tmp.replace(path)


def _read_manifest():
    if not PHASE2_MANIFEST_PATH.exists():
        return {"runs": []}
    try:
        return json.loads(PHASE2_MANIFEST_PATH.read_text(encoding="utf-8"))
    except Exception:
        return {"runs": []}


def _write_manifest(manifest):
    tmp = phase2_cache_dir / (PHASE2_MANIFEST_PATH.name + ".tmp")
    tmp.write_text(json.dumps(manifest, indent=2, default=str), encoding="utf-8")
    tmp.replace(PHASE2_MANIFEST_PATH)


def _export_cv_and_summary(cache_stem, r, mn, mode, fs_name):
    """Full per-parameter CV metrics (CSV) + compact summary (JSON)."""
    cv_df = r["cv_results"].copy()
    cv_df.insert(0, "feature_set", fs_name)
    cv_df.insert(0, "eval_mode", mode)
    cv_df.insert(0, "model", mn)
    csv_path = phase2_cache_dir / f"{cache_stem}_cv_results.csv"
    cv_df.to_csv(csv_path, index=False)
    summ = {
        "model": mn,
        "eval_mode": mode,
        "feature_set": fs_name,
        "best_params": r["best_params"],
        "best_cv_f1_macro": float(r["best_cv"]),
        "test_acc": float(r["acc"]),
        "test_f1_macro": float(r["f1m"]),
        "fit_time_s": float(r["fit_t"]),
        "predict_time_s": float(r["pred_t"]),
        "n_candidates": int(len(cv_df)),
        "cv_results_csv": str(csv_path.resolve()),
    }
    json_path = phase2_cache_dir / f"{cache_stem}_summary.json"
    json_path.write_text(json.dumps(summ, indent=2, default=str), encoding="utf-8")
    return csv_path, json_path


def _ensure_legacy_sidecars(cache_file: Path, payload, mn, mode, fs_name):
    """Older checkpoints had only .pkl — add meta + CSV/JSON once (no manifest append)."""
    meta_path = cache_file.with_suffix(".meta.json")
    if meta_path.exists():
        return
    stem = cache_file.stem
    csv_path, json_path = _export_cv_and_summary(stem, payload, mn, mode, fs_name)
    meta = {
        "model": mn,
        "eval_mode": mode,
        "feature_set": fs_name,
        "cache_pkl": str(cache_file.resolve()),
        "saved_at_utc": datetime.now(timezone.utc).isoformat(),
        "best_cv": float(payload["best_cv"]),
        "acc": float(payload["acc"]),
        "f1_macro": float(payload["f1m"]),
        "cv_results_csv": str(csv_path.resolve()),
        "summary_json": str(json_path.resolve()),
        "migrated_from_pkl_only": True,
    }
    meta_path.write_text(json.dumps(meta, indent=2, default=str), encoding="utf-8")
    print(f"  [MIGRATE] wrote sidecars for legacy checkpoint {cache_file.name}")


def _persist_phase2_job(cache_file: Path, payload, mn, mode, fs_name):
    stem = cache_file.stem
    csv_path, json_path = _export_cv_and_summary(stem, payload, mn, mode, fs_name)
    meta = {
        "model": mn,
        "eval_mode": mode,
        "feature_set": fs_name,
        "cache_pkl": str(cache_file.resolve()),
        "saved_at_utc": datetime.now(timezone.utc).isoformat(),
        "best_cv": float(payload["best_cv"]),
        "acc": float(payload["acc"]),
        "f1_macro": float(payload["f1m"]),
        "cv_results_csv": str(csv_path.resolve()),
        "summary_json": str(json_path.resolve()),
    }
    meta_path = cache_file.with_suffix(".meta.json")
    meta_path.write_text(json.dumps(meta, indent=2, default=str), encoding="utf-8")
    _atomic_joblib_dump(_sanitize_phase2_payload(payload), cache_file)
    man = _read_manifest()
    man.setdefault("runs", [])
    man["runs"].append(meta)
    _write_manifest(man)


def phase2_hydrate_from_disk(model_name=None):
    """Rebuild P2_ALL / P2 from checkpoint files (e.g. after kernel restart)."""
    n = 0
    for meta_path in sorted(phase2_cache_dir.glob("*.meta.json")):
        try:
            meta = json.loads(meta_path.read_text(encoding="utf-8"))
        except Exception:
            continue
        mn = meta.get("model")
        if model_name is not None and mn != model_name:
            continue
        pkl_path = Path(meta["cache_pkl"])
        if not pkl_path.exists():
            pkl_path = meta_path.with_suffix(".pkl")
        if not pkl_path.exists():
            continue
        r = _safe_joblib_load(pkl_path)
        if r is None:
            continue
        mode = meta["eval_mode"]
        fs_name = meta["feature_set"]
        P2_ALL.setdefault(mode, {}).setdefault(fs_name, {})[mn] = r
        if mode == "split":
            P2.setdefault(fs_name, {})[mn] = r
        n += 1
    if n:
        print(f"phase2_hydrate_from_disk: loaded {n} completed job(s)" + (f" for {model_name}" if model_name else ""))


P2_ALL = {}
P2 = {}


def run_phase2_for_model(mn):
    if mn not in ESTIMATORS:
        raise ValueError(f"Unknown model {mn!r}; use one of {list(ESTIMATORS)}")
    phase2_hydrate_from_disk(mn)
    est = ESTIMATORS[mn]
    for mode in EVAL_MODES:
        print(f"\nMode: {mode}  |  model: {mn}")
        print("=" * 65)
        P2_ALL.setdefault(mode, {})
        for fs_name, (Xtr, Xte) in CLEAN_OPT.items():
            print(f"\n{'─' * 60}")
            print(f"Feature set: {fs_name}  ({Xtr.shape[1]} features)")
            P2_ALL[mode].setdefault(fs_name, {})
            cache_file = _phase2_cache_file(mode, fs_name, mn)
            print(f"  {mn}  checkpoint: {cache_file.name}", flush=True)
            r = None
            if USE_PHASE_CACHE and cache_file.exists() and not FORCE_RECOMPUTE_CACHE:
                r = _safe_joblib_load(cache_file)
                if "estimator" in r and "cv_results" in r:
                    pl = {
                        k: v
                        for k, v in r.items()
                        if k
                        in {
                            "eval_mode",
                            "best_params",
                            "best_cv",
                            "acc",
                            "f1m",
                            "f1w",
                            "prec",
                            "rec",
                            "fit_t",
                            "pred_t",
                            "cv_results",
                            "y_pred",
                            "estimator",
                        }
                    }
                    _ensure_legacy_sidecars(cache_file, pl, mn, mode, fs_name)
                    print(f"  [RESUME] loaded from disk — acc={r['acc']:.3f}  f1_macro={r['f1m']:.3f}")
                else:
                    print("  [RESUME] cache missing fields — re-running …")
                    r = None
            if r is None:
                r = run_grid(
                    est.__class__(**est.get_params()),
                    MODEL_GRIDS[mn],
                    Xtr,
                    Xte,
                    mode,
                    mn,
                    fs_name,
                )
                payload = {
                    k: v
                    for k, v in r.items()
                    if k
                    in {
                        "eval_mode",
                        "best_params",
                        "best_cv",
                        "acc",
                        "f1m",
                        "f1w",
                        "prec",
                        "rec",
                        "fit_t",
                        "pred_t",
                        "cv_results",
                        "y_pred",
                        "estimator",
                    }
                }
                if USE_PHASE_CACHE:
                    _persist_phase2_job(cache_file, payload, mn, mode, fs_name)
                    print(f"  [SAVE] metrics + CV grid → {cache_file.name}, *.meta.json, *_cv_results.csv")
                r = payload
            P2_ALL[mode][fs_name][mn] = r
            if mode == "split":
                P2.setdefault(fs_name, {})[mn] = r
            print(f"  done  acc={r['acc']:.3f}  f1={r['f1m']:.3f}  fit_t={r['fit_t']:.1f}s")

def phase2_finalize_metrics():
    # Build PHASE2_ALL_METRICS_DF and save CSV / cache from whatever is in P2_ALL.
    global PHASE2_ALL_METRICS_DF
    if not P2_ALL:
        print("P2_ALL is empty — loading completed jobs from disk (all models) …")
        phase2_hydrate_from_disk()
    if not P2_ALL:
        print("Warning: nothing to export. Run the Phase 2 model cells first, or check", phase2_cache_dir)
        return
    rows = []
    for mode in EVAL_MODES:
        if mode not in P2_ALL:
            continue
        for fs_name in CLEAN_OPT:
            if fs_name not in P2_ALL[mode]:
                continue
            for mn, r in P2_ALL[mode][fs_name].items():
                rows.append({
                    "eval_mode": mode,
                    "feature_set": fs_name,
                    "model": mn,
                    "acc": r["acc"],
                    "f1_macro": r["f1m"],
                    "f1_weighted": r["f1w"],
                    "precision_macro": r["prec"],
                    "recall_macro": r["rec"],
                    "fit_time_s": r["fit_t"],
                    "predict_time_s": r["pred_t"],
                    "best_cv": r["best_cv"],
                    "best_params": str(r["best_params"]),
                })
    PHASE2_ALL_METRICS_DF = pd.DataFrame(rows)
    PHASE2_ALL_METRICS_DF.to_csv("phase2_all_modes_metrics.csv", index=False)
    if USE_PHASE_CACHE:
        joblib.dump(PHASE2_ALL_METRICS_DF, PHASE_CACHE_DIR / "phase2_all_metrics_df.pkl")
        models_dir = PHASE_CACHE_DIR / "saved_models"
        models_dir.mkdir(parents=True, exist_ok=True)
        for fs_name, model_dict in P2.items():
            for model_name, result in model_dict.items():
                est = result.get("estimator", None)
                if est is not None:
                    tag = f"split|{fs_name}|{model_name}|seed={SEED}|cv={CV_FOLDS}"
                    h = hashlib.md5(tag.encode("utf-8")).hexdigest()[:12]
                    joblib.dump(est, models_dir / f"{h}.joblib")
    print("\nBenchmark finalize complete.")
    print("Saved: phase2_all_modes_metrics.csv")
    print(f"Per-grid CV tables + summaries: {phase2_cache_dir}/*_cv_results.csv and *_summary.json")
    print(f"Checkpoint log: {PHASE2_MANIFEST_PATH}")

# %%
# Phase 2 — SVM only
run_phase2_for_model("SVM")

# %%
# Phase 2 — KNN only
run_phase2_for_model("KNN")

# %%
# Phase 2 — Random Forest only
run_phase2_for_model("RF")

# %%
# Phase 2 — export metrics (run after the model cells you need)
phase2_finalize_metrics()

# %% [markdown]
# ## 12. Per-Feature-Set Result Plots

# %%
# Model colours (used by Phase 2 plots; safe if this cell runs standalone)
PALETTE = {"SVM": "#4C72B0", "KNN": "#DD8452", "RF": "#55A868"}

def _hp_label(row, mn):
    if mn=="SVM":
        k = row.get('param_kernel', '?')
        c = row.get('param_C', '?')
        g = row.get('param_gamma', '?')
        return f"{k} C={c} gamma={g}" if k == "rbf" else f"{k} C={c}"
    if mn=="KNN": return f"k={row.get('param_n_neighbors','?')} {str(row.get('param_metric','?'))[:3]}"
    return f"n={row.get('param_n_estimators','?')} d={row.get('param_max_depth','?')}"

def plot_fs(fs_name, res_dict):
    # Only models present in P2 for this feature set (split mode may be partial).
    order = ["SVM", "KNN", "RF"]
    mnames = [m for m in order if m in res_dict]
    if not mnames:
        print(f"  Skipping {fs_name}: no model results (run Phase 2 split cells for this set).")
        return
    missing = [m for m in order if m not in res_dict]
    n = len(mnames)
    fig_w = max(10.0, 7.0 * n)
    fig = plt.figure(figsize=(fig_w, 16))
    sub = f"Feature Set: {fs_name}  [Optimal Parameters]"
    if missing:
        sub += f"  —  missing: {', '.join(missing)} (not run or not in P2)"
    fig.suptitle(sub, fontsize=15, fontweight="bold", y=0.99)
    outer = gridspec.GridSpec(3, 1, figure=fig, hspace=0.45,
                              height_ratios=[1.0, 1.5, 1.1])

    # Metric bar chart
    ax1 = fig.add_subplot(outer[0])
    mk = ["acc", "f1m", "prec", "rec"]
    ml = ["Accuracy", "F1-macro", "Precision", "Recall"]
    x = np.arange(4)
    w = min(0.22, 0.75 / max(n, 1))
    for i, mn in enumerate(mnames):
        vals = [res_dict[mn][k] for k in mk]
        offset = (i - (n - 1) / 2) * w
        bars = ax1.bar(
            x + offset, vals, w, label=mn,
            color=PALETTE[mn], edgecolor="white",
        )
        ax1.bar_label(bars, fmt="%.3f", fontsize=8, padding=1)
    ax1.set_xticks(x)
    ax1.set_xticklabels(ml)
    ax1.set_ylim(0, 1.15)
    ax1.set_ylabel("Score")
    ax1.set_title("Best-config Test Metrics", fontsize=11)
    ax1.legend(fontsize=9)
    ax1.axhline(0.5, color="gray", lw=0.8, ls="--", alpha=0.4)

    inner = gridspec.GridSpecFromSubplotSpec(1, n, subplot_spec=outer[1], wspace=0.38)
    for col, mn in enumerate(mnames):
        ax = fig.add_subplot(inner[col])
        cv = (
            res_dict[mn]["cv_results"]
            .sort_values("mean_test_score", ascending=False)
            .head(20)
            .copy()
        )
        cv["label"] = cv.apply(lambda r: _hp_label(r, mn), axis=1)
        yp = np.arange(len(cv))
        ax.barh(
            yp, cv["mean_test_score"], xerr=cv["std_test_score"],
            color=PALETTE[mn], alpha=0.75, error_kw={"elinewidth": 0.8},
        )
        ax.set_yticks(yp)
        ax.set_yticklabels(cv["label"], fontsize=7)
        ax.set_xlabel("CV F1-macro", fontsize=9)
        ax.set_title(f"{mn} — Top 20 configs", fontsize=10, fontweight="bold")
        ax.set_xlim(0, 1)
        ax.axvline(cv["mean_test_score"].max(), color="red", lw=1.2, ls="--", alpha=0.6)

    inner2 = gridspec.GridSpecFromSubplotSpec(1, n, subplot_spec=outer[2], wspace=0.38)
    for col, mn in enumerate(mnames):
        ax = fig.add_subplot(inner2[col])
        cm = confusion_matrix(y_test, res_dict[mn]["y_pred"], normalize="true")
        ax.imshow(cm, cmap="Blues", vmin=0, vmax=1)
        ax.set_xticks(range(n_classes))
        ax.set_yticks(range(n_classes))
        ax.set_xticklabels(class_names, rotation=35, ha="right", fontsize=8)
        ax.set_yticklabels(class_names, fontsize=8)
        ax.set_xlabel("Predicted", fontsize=8)
        ax.set_ylabel("True", fontsize=8)
        ax.set_title(f"{mn} — CM", fontsize=10, fontweight="bold")
        for i in range(n_classes):
            for j in range(n_classes):
                ax.text(
                    j, i, f"{cm[i, j]:.2f}", ha="center", va="center",
                    fontsize=7, color="white" if cm[i, j] > 0.6 else "black",
                )

    fname = OUTPUT_DIR / f"p2_{fs_name.replace(' ','_').replace('+','p')}.png"
    plt.savefig(fname, dpi=110, bbox_inches="tight")
    plt.show()
    print(f"  Saved: {fname}")


for fs_name, res_dict in P2.items():
    print(f"\nPlotting: {fs_name}")
    if not res_dict:
        print("  (empty — no split-mode results)")
        continue
    plot_fs(fs_name, res_dict)

# %% [markdown]
# ## 13. Overall Performance Dashboard

# %%
fs_list = list(P2.keys())
mnames  = ["SVM","KNN","RF"]

fig = plt.figure(figsize=(24, 22))
fig.suptitle("Overall Dashboard — Optimal Feature Parameters + Model Benchmark",
             fontsize=15, fontweight="bold", y=0.99)
outer = gridspec.GridSpec(3, 1, figure=fig, hspace=0.45)

# ── Grouped bar: F1-macro ─────────────────────────────────────────────────
ax1 = fig.add_subplot(outer[0])
x, w = np.arange(len(fs_list)), 0.25
for i, mn in enumerate(mnames):
    vals = [P2[fs][mn]["f1m"] for fs in fs_list]
    bars = ax1.bar(x+(i-1)*w, vals, w, label=mn,
                   color=PALETTE[mn], edgecolor="white")
    ax1.bar_label(bars, fmt="%.3f", fontsize=7.5, padding=1, rotation=90)
ax1.set_xticks(x); ax1.set_xticklabels(fs_list, rotation=20, ha="right", fontsize=9)
ax1.set_ylim(0, 1.20); ax1.set_ylabel("Test F1-macro")
ax1.set_title("Test F1-macro — All Feature Sets × Models (Optimal Params)", fontsize=12, fontweight="bold")
ax1.legend(fontsize=10)
ax1.axhline(0.5, color="gray", lw=0.8, ls="--", alpha=0.4)

# ── Heatmap: F1-macro ─────────────────────────────────────────────────────
ax2 = fig.add_subplot(outer[1])
hdata = pd.DataFrame(
    {mn: [P2[fs][mn]["f1m"] for fs in fs_list] for mn in mnames},
    index=fs_list)
sns.heatmap(hdata, ax=ax2, annot=True, fmt=".3f", cmap="YlGnBu",
            vmin=0, vmax=1, linewidths=0.5, linecolor="white",
            cbar_kws={"label":"Test F1-macro"})
ax2.set_title("F1-macro Heatmap", fontsize=12, fontweight="bold")
ax2.tick_params(axis="x", rotation=0); ax2.tick_params(axis="y", rotation=0)

# ── Scatter: training time vs F1-macro ────────────────────────────────────
ax3 = fig.add_subplot(outer[2])
for mn in mnames:
    times = [P2[fs][mn]["fit_t"] for fs in fs_list]
    f1s   = [P2[fs][mn]["f1m"]   for fs in fs_list]
    ax3.scatter(times, f1s, s=90, label=mn, color=PALETTE[mn],
                edgecolors="white", zorder=3)
    for fi, fs in enumerate(fs_list):
        ax3.annotate(fs[:9], (times[fi], f1s[fi]),
                     textcoords="offset points", xytext=(4,2), fontsize=6.5)
ax3.set_xlabel("Training time (s)"); ax3.set_ylabel("Test F1-macro")
ax3.set_title("Training Time vs F1-macro Trade-off", fontsize=12, fontweight="bold")
ax3.legend(fontsize=10); ax3.grid(True, alpha=0.3)

plt.savefig(OUTPUT_DIR / "p2_overall_dashboard.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: p2_overall_dashboard.png")

# %% [markdown]
# ## 14. Leaderboard & Final Summary

# %%
rows = []
for fs in fs_list:
    for mn in mnames:
        r = P2[fs][mn]
        rows.append({"Feature Set":fs, "Model":mn,
                     "Accuracy":r["acc"], "F1-macro":r["f1m"],
                     "F1-weighted":r["f1w"], "Precision":r["prec"],
                     "Recall":r["rec"], "Fit Time (s)":r["fit_t"],
                     "Best Params":str(r["best_params"])})

leader = pd.DataFrame(rows)
mms2 = MinMaxScaler()
leader["time_n"] = mms2.fit_transform(leader[["Fit Time (s)"]])
leader["Composite"] = (0.50*leader["F1-macro"] + 0.30*leader["Accuracy"]
                       + 0.10*leader["Precision"] + 0.10*leader["Recall"]
                       - 0.05*leader["time_n"]).round(4)
leader = leader.sort_values("Composite", ascending=False).reset_index(drop=True)
leader.index += 1

print("LEADERBOARD")
display(leader[["Feature Set","Model","Accuracy","F1-macro",
                "Precision","Recall","Fit Time (s)","Composite"]].round(4))
leader.to_csv("phase2_benchmark_results.csv", index=False)

# ── Leaderboard bar chart ─────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(14, 7))
top = leader.head(min(20, len(leader)))
bar_cols = [PALETTE[m] for m in top["Model"]]
bars = ax.barh(range(len(top))[::-1], top["Composite"],
               color=bar_cols, edgecolor="white")
ax.set_yticks(range(len(top))[::-1])
ax.set_yticklabels([f"{r['Feature Set']} | {r['Model']}"
                    for _, r in top.iterrows()], fontsize=9)
ax.set_xlabel("Composite Score")
ax.set_title("Final Leaderboard — Optimal Feature Params + Tuned Models",
             fontsize=13, fontweight="bold")
from matplotlib.patches import Patch
ax.legend(handles=[Patch(facecolor=PALETTE[m],label=m) for m in mnames],
          fontsize=10, loc="lower right")
ax.bar_label(bars, fmt="%.4f", fontsize=8, padding=2)
ax.set_xlim(0, 1.08)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "p2_leaderboard.png", dpi=120, bbox_inches="tight")
plt.show()

print("\nSaved: phase2_benchmark_results.csv, p2_leaderboard.png")

# %%
# ── Final print summary ────────────────────────────────────────────────────
print("=" * 65)
print("FINAL SUMMARY")
print("=" * 65)

best = leader.iloc[0]
print(f"\n🏆  Best overall:")
print(f"     Feature Set : {best['Feature Set']}")
print(f"     Model       : {best['Model']}")
print(f"     Accuracy    : {best['Accuracy']:.4f}")
print(f"     F1-macro    : {best['F1-macro']:.4f}")
print(f"     Composite   : {best['Composite']:.4f}")

print(f"\n📊  Best per model:")
for mn in mnames:
    sub = leader[leader["Model"]==mn].iloc[0]
    print(f"     {mn:4s}  Feature Set: {sub['Feature Set']:20s}  "
          f"F1={sub['F1-macro']:.4f}")

print(f"\n📦  Best per feature set:")
for fs in fs_list:
    sub = leader[leader["Feature Set"]==fs].iloc[0]
    print(f"     {fs:18s}  {sub['Model']:4s}  F1={sub['F1-macro']:.4f}")

print(f"\n⚙️   Optimal feature parameters used:")
print(f"     GLCM: dist={BEST_GLCM_DIST}  ang={len(BEST_GLCM_ANG)} angles  "
      f"lvl={BEST_GLCM_LVL}  sym={BEST_GLCM_SYM}")
print(f"     LBP : P={BEST_LBP_P}  R={BEST_LBP_R}  method={BEST_LBP_METHOD}")
print(f"     DWT : wavelet={BEST_DWT_WAV}  level={BEST_DWT_LEVEL}")

print(f"\n📁  Output files:")
for f in [
          "phase2_benchmark_results.csv",
          "phase2_all_modes_metrics.csv",
          "seed_stability_3seeds.csv",
          "output/class_balance_train.png",
          "output/rf_branch_importance.png",
          "output/tsne_best_feature_set.png",
          "output/glcm_param_search.png", "output/glcm_top15.png",
          "output/lbp_param_search.png", "output/lbp_by_method.png",
          "output/dwt_param_search.png", "output/dwt_wavelet_comparison.png",
          "output/phase1_summary.png",
          "output/p2_overall_dashboard.png", "output/p2_leaderboard.png"]:
    print(f"     {f}")

# %% [markdown]
# ## 15. Diagnostics: Imbalance, RF Importances, t-SNE, Seed Stability

# %%
from collections import Counter
from sklearn.manifold import TSNE

# %% [markdown]
# ### Class imbalance check

# %%
train_counter = Counter(y_train)
imbalance_ratio = max(train_counter.values()) / max(1, min(train_counter.values()))

print("Train class balance:", train_counter)
print(f"Imbalance ratio: {imbalance_ratio:.3f}")

fig, ax = plt.subplots(figsize=(8, 4.5))
cls_idx = list(range(len(class_names)))
cls_counts = [train_counter.get(i, 0) for i in cls_idx]
bars = ax.bar(class_names, cls_counts, color=sns.color_palette("Set2", len(class_names)))
ax.set_title("Train Class Distribution")
ax.set_ylabel("Count")
ax.set_xlabel("Class")
ax.bar_label(bars, padding=2)
plt.xticks(rotation=20, ha="right")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "class_balance_train.png", dpi=120, bbox_inches="tight")
plt.show()

if imbalance_ratio >= 1.5:
    print("Note: noticeable imbalance detected. Consider trying class_weight and/or SMOTE in a controlled experiment.")
else:
    print("Class balance looks reasonably even. SMOTE likely optional.")

# %% [markdown]
# ### RF branch importance visualisation (A / GLCM / LBP / DWT / HOG)

# %%
rf_full = RandomForestClassifier(
    random_state=SEED,
    n_jobs=-1,
    **P2["Full(opt)"]["RF"]["best_params"]
)
rf_full.fit(FULL_tr, y_train)

importances = rf_full.feature_importances_
a = A_tr.shape[1]
bg = B_glcm_tr.shape[1]
bl = B_lbp_tr.shape[1]
c = C_tr.shape[1]
d = D_tr.shape[1]

branch_importance = {
    "A_Stats": float(importances[:a].sum()),
    "B_GLCM": float(importances[a:a+bg].sum()),
    "B_LBP": float(importances[a+bg:a+bg+bl].sum()),
    "C_DWT": float(importances[a+bg+bl:a+bg+bl+c].sum()),
    "D_HOG": float(importances[a+bg+bl+c:a+bg+bl+c+d].sum()),
}
branch_imp_df = pd.DataFrame(
    {"branch": list(branch_importance.keys()), "importance": list(branch_importance.values())}
).sort_values("importance", ascending=False)

fig, ax = plt.subplots(figsize=(9, 4.8))
bars = ax.bar(branch_imp_df["branch"], branch_imp_df["importance"], color=sns.color_palette("viridis", len(branch_imp_df)))
ax.set_title("RF Branch Importances (trained on Full(opt))")
ax.set_ylabel("Summed feature_importances_")
ax.set_xlabel("Feature branch")
ax.bar_label(bars, fmt="%.3f", padding=2)
plt.xticks(rotation=15, ha="right")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "rf_branch_importance.png", dpi=120, bbox_inches="tight")
plt.show()

display(branch_imp_df)

# %% [markdown]
# ### t-SNE on best feature set

# %%
best_fs_tsne = leader.iloc[0]["Feature Set"]
X_best_train = CLEAN_OPT[best_fs_tsne][0]

n_tsne = min(500, X_best_train.shape[0])
rng = np.random.default_rng(SEED)
idx_tsne = rng.choice(X_best_train.shape[0], size=n_tsne, replace=False)
X_tsne = X_best_train[idx_tsne]
y_tsne = y_train[idx_tsne]

Xr = TSNE(n_components=2, random_state=SEED, init="pca", learning_rate="auto").fit_transform(X_tsne)

fig, ax = plt.subplots(figsize=(7, 6))
sc = ax.scatter(Xr[:, 0], Xr[:, 1], c=y_tsne, cmap="tab10", s=18, alpha=0.85)
ax.set_title(f"t-SNE projection (best feature set: {best_fs_tsne}, n={n_tsne})")
ax.set_xlabel("t-SNE 1")
ax.set_ylabel("t-SNE 2")
handles, _ = sc.legend_elements()
ax.legend(handles, class_names, title="Class", bbox_to_anchor=(1.03, 1), loc="upper left")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "tsne_best_feature_set.png", dpi=120, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Seed stability check (3 seeds)

# %%
best_fs = leader.iloc[0]["Feature Set"]
best_model = leader.iloc[0]["Model"]

X_raw = np.vstack([OPT_SETS[best_fs][0], OPT_SETS[best_fs][1]])
y_all_diag = np.concatenate([y_train, y_test])

seed_results = []
for sd in [SEED, SEED + 1, SEED + 2]:
    Xtr_s, Xte_s, ytr_s, yte_s = train_test_split(
        X_raw, y_all_diag, test_size=TEST_SIZE, stratify=y_all_diag, random_state=sd
    )
    Xtr_s, Xte_s, _ = clean_scale(Xtr_s.astype(np.float32), Xte_s.astype(np.float32))

    cv_s = StratifiedKFold(n_splits=3, shuffle=True, random_state=sd)
    est_s = ESTIMATORS[best_model].__class__(**ESTIMATORS[best_model].get_params())

    gs_s = GridSearchCV(
        est_s,
        MODEL_GRIDS[best_model],
        scoring="f1_macro",
        cv=cv_s,
        n_jobs=-1,
        refit=True,
        return_train_score=False,
    )
    gs_s.fit(Xtr_s, ytr_s)
    yp_s = gs_s.best_estimator_.predict(Xte_s)

    seed_results.append({
        "seed": sd,
        "acc": accuracy_score(yte_s, yp_s),
        "f1_macro": f1_score(yte_s, yp_s, average="macro", zero_division=0),
        "best_params": str(gs_s.best_params_),
    })

seed_df = pd.DataFrame(seed_results)
mu = seed_df["f1_macro"].mean()
sig = seed_df["f1_macro"].std(ddof=1) if len(seed_df) > 1 else 0.0
ci95 = 1.96 * sig / np.sqrt(len(seed_df)) if len(seed_df) > 1 else 0.0

print(f"\nSeed stability for best pair ({best_fs}, {best_model}):")
print(seed_df.to_string(index=False))
print(f"F1-macro mean ± 95% CI: {mu:.4f} ± {ci95:.4f}")

seed_df.to_csv("seed_stability_3seeds.csv", index=False)
print("Saved: class_balance_train.png, rf_branch_importance.png, tsne_best_feature_set.png, seed_stability_3seeds.csv")

# %% [markdown]
# ## Inference test on a random test image

# %%
# ── Inference test on all models (same random test image) ──────────────────
# Uses all (feature_set, model) pairs from P2 and compares predictions.

import math, hashlib, joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 1) Pick one random test sample
rng = np.random.default_rng(42)
idx = int(rng.integers(0, len(y_test)))
img = X_test_raw[idx]
y_true = int(y_test[idx])
true_name = class_names[y_true]

rows = []

def _load_estimator_if_needed(fs_name, model_name, est):
    if est is not None:
        return est
    models_dir = PHASE_CACHE_DIR / "saved_models"
    tag = f"split|{fs_name}|{model_name}|seed={SEED}|cv={CV_FOLDS}"
    h = hashlib.md5(tag.encode("utf-8")).hexdigest()[:12]
    model_path = models_dir / f"{h}.joblib"
    if model_path.exists():
        return joblib.load(model_path)
    return None

# 2) Predict with every model from P2
for fs_name, model_dict in P2.items():
    Xte_best = CLEAN_OPT[fs_name][1]
    x_input = Xte_best[idx:idx+1]

    for model_name, result in model_dict.items():
        est = _load_estimator_if_needed(fs_name, model_name, result.get("estimator", None))
        if est is None:
            rows.append({
                "feature_set": fs_name,
                "model": model_name,
                "pred_name": "N/A",
                "confidence": np.nan,
                "correct": False,
                "status": "MISSING_ESTIMATOR"
            })
            continue

        y_pred = int(est.predict(x_input)[0])
        pred_name = class_names[y_pred]
        correct = (y_pred == y_true)

        if hasattr(est, "predict_proba"):
            proba = est.predict_proba(x_input)[0]
            conf = float(proba[y_pred])
        else:
            conf = np.nan

        rows.append({
            "feature_set": fs_name,
            "model": model_name,
            "pred_name": pred_name,
            "confidence": conf,
            "correct": correct,
            "status": "OK"
        })

inf_df = pd.DataFrame(rows)
inf_df["pair"] = inf_df["feature_set"] + " | " + inf_df["model"]

print("Selected test index:", idx)
print("True label:", true_name)
display(
    inf_df.sort_values(["correct", "confidence"], ascending=[False, False])
          [["feature_set","model","pred_name","confidence","correct","status"]]
)

# 3) Plot A: confidence per model pair (colored by correctness)
plot_df = inf_df[inf_df["status"] == "OK"].copy()
plot_df["confidence_plot"] = plot_df["confidence"].fillna(0.0)
plot_df = plot_df.sort_values(["correct", "confidence_plot"], ascending=[False, False])

colors = np.where(plot_df["correct"], "#2ca02c", "#d62728")
plt.figure(figsize=(14, 6))
plt.bar(range(len(plot_df)), plot_df["confidence_plot"], color=colors)
plt.xticks(range(len(plot_df)), plot_df["pair"], rotation=70, ha="right")
plt.ylim(0, 1.05)
plt.ylabel("Prediction confidence (if available)")
plt.title(f"All-model inference on one random test image | True: {true_name}")
plt.tight_layout()
plt.show()

# 4) Plot B: one tile per model pair (same image, different predictions)
n = len(plot_df)
ncols = 4
nrows = math.ceil(n / ncols)
fig, axes = plt.subplots(nrows, ncols, figsize=(4*ncols, 3.8*nrows))
axes = np.array(axes).reshape(-1)

for i, (_, r) in enumerate(plot_df.iterrows()):
    ax = axes[i]
    ax.imshow(img, cmap="gray")
    ax.axis("off")
    conf_txt = f"{r['confidence']:.2f}" if np.isfinite(r["confidence"]) else "NA"
    color = "green" if r["correct"] else "red"
    ax.set_title(f"{r['feature_set']} | {r['model']}\nPred: {r['pred_name']} (conf={conf_txt})",
                 fontsize=9, color=color)

for j in range(i+1, len(axes)):
    axes[j].axis("off")

fig.suptitle(f"Per-model predictions on same test sample (true: {true_name})", y=1.01)
plt.tight_layout()
plt.show()

# %%
# ── Accuracy plots by eval_mode ─────────────────────────────────────────────
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("phase2_all_modes_metrics.csv")

# Keep consistent order
mode_order = ["split", "cv_1", "cv_2", "cv_3", "cv_4", "cv_5"]
df = df[df["eval_mode"].isin(mode_order)].copy()
df["eval_mode"] = pd.Categorical(df["eval_mode"], categories=mode_order, ordered=True)

# Plot 1: Mean accuracy per mode and model
agg = (df.groupby(["eval_mode", "model"], as_index=False)["acc"]
         .mean()
         .sort_values(["eval_mode", "acc"], ascending=[True, False]))

plt.figure(figsize=(10, 5))
sns.barplot(data=agg, x="eval_mode", y="acc", hue="model")
plt.title("Mean Accuracy by Evaluation Mode and Model")
plt.ylabel("Accuracy")
plt.xlabel("Evaluation mode")
plt.ylim(0.65, 0.95)
plt.grid(axis="y", alpha=0.25)
plt.tight_layout()
plt.show()

# Plot 2: One panel per mode, accuracy across feature sets
g = sns.catplot(
    data=df,
    kind="bar",
    x="feature_set",
    y="acc",
    hue="model",
    col="eval_mode",
    col_wrap=3,
    sharey=True,
    height=3.6,
    aspect=1.35
)
g.set_titles("{col_name}")
for ax in g.axes.flatten():
    ax.tick_params(axis="x", rotation=60)
    ax.set_ylim(0.65, 0.95)
g.fig.subplots_adjust(top=0.90)
g.fig.suptitle("Accuracy per Feature Set for Each Evaluation Mode")
plt.show()

# %%
# ── Best model per feature set per mode (heatmap + labels) ─────────────────
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("phase2_all_modes_metrics.csv")

mode_order = ["split", "cv_1", "cv_2", "cv_3", "cv_4", "cv_5"]
df = df[df["eval_mode"].isin(mode_order)].copy()
df["eval_mode"] = pd.Categorical(df["eval_mode"], categories=mode_order, ordered=True)

# 1) For each (mode, feature_set), pick row with max accuracy
best_idx = df.groupby(["eval_mode", "feature_set"])["acc"].idxmax()
best_df = df.loc[best_idx, ["eval_mode", "feature_set", "model", "acc"]].copy()

# 2) Build matrices: one for accuracy values, one for model labels
acc_mat = best_df.pivot(index="feature_set", columns="eval_mode", values="acc")
model_mat = best_df.pivot(index="feature_set", columns="eval_mode", values="model")

# Keep feature set order close to your report/notebook convention
feature_order = [
    "A — Stats", "B — Tex(opt)", "C — DWT(opt)", "D — HOG",
    "A+B", "B+C(opt)", "A+B+C(opt)", "Full(opt)"
]
existing = [f for f in feature_order if f in acc_mat.index]
remaining = [f for f in acc_mat.index if f not in existing]
acc_mat = acc_mat.loc[existing + remaining, mode_order]
model_mat = model_mat.loc[existing + remaining, mode_order]

# 3) Annotation text: "MODEL\n0.xxx"
annot = model_mat.astype(str) + "\n" + acc_mat.applymap(lambda x: f"{x:.3f}")

plt.figure(figsize=(12, 6))
ax = sns.heatmap(
    acc_mat,
    annot=annot,
    fmt="",
    cmap="YlGnBu",
    vmin=0.65,
    vmax=0.93,
    linewidths=0.5,
    cbar_kws={"label": "Best accuracy per (mode, feature set)"}
)
ax.set_title("Best Model per Feature Set Across Evaluation Modes")
ax.set_xlabel("Evaluation mode")
ax.set_ylabel("Feature set")
plt.tight_layout()
plt.show()

# Optional: compact table for speaking notes
display(best_df.sort_values(["eval_mode", "acc"], ascending=[True, False]))

# %% [markdown]
# ## 16. Statistical Validation
#
# This section provides a **complete statistical framework** to assess whether observed
# performance differences between models are meaningful, stable, and reproducible.
#
# | Test | Purpose |
# |------|---------|
# | **Cohen's Kappa** | Agreement beyond random chance per model |
# | **Bootstrap CI (95%)** | Confidence interval for F1-macro and Accuracy |
# | **CV fold statistics** | Mean ± Std across all CV folds |
# | **McNemar's test** | Pairwise classifier significance on same test set |
# | **Wilcoxon signed-rank** | Paired non-parametric test across CV folds |
# | **Friedman + Nemenyi** | Multi-classifier comparison + post-hoc ranking |
# | **Summary table** | Publication-ready statistical results |

# %%
# %pip install -q scikit_posthocs

# %%
# ── Statistical validation imports ────────────────────────────────────────
from scipy.stats import (
    wilcoxon,          # Paired non-parametric test (two classifiers, same CV folds)
    friedmanchisquare, # Non-parametric multi-group test (k classifiers, n CV folds)
    chi2_contingency,  # Base for McNemar's continuity
)
from scipy.stats import bootstrap as scipy_bootstrap
from sklearn.metrics import cohen_kappa_score
import scikit_posthocs as sp   # Post-hoc Nemenyi test after Friedman
import warnings
warnings.filterwarnings("ignore")

print("Statistical validation libraries loaded.")

# %% [markdown]
# ### 15a. Cohen's Kappa (κ)
#
# **Cohen's Kappa** measures agreement between predictions and ground truth beyond what
# random chance would produce. Unlike accuracy, it accounts for class imbalance.
#
# | κ range | Interpretation |
# |---------|---------------|
# | < 0.20 | Slight agreement |
# | 0.20–0.40 | Fair agreement |
# | 0.40–0.60 | Moderate agreement |
# | 0.60–0.80 | Substantial agreement |
# | **> 0.80** | **Almost perfect** |

# %%
# ── Cohen's Kappa for every (Feature Set × Model) on split test ────────────
# cohen_kappa_score(y_true, y_pred) — computes κ from the confusion matrix.
# We use the split predictions stored in P2 which are the held-out test set.

# Keep this cell self-contained so it works regardless of execution order.
if "P2" not in globals() or not P2:
    if "P2_ALL" in globals() and "split" in P2_ALL and P2_ALL["split"]:
        P2 = P2_ALL["split"]
    else:
        raise NameError(
            "P2 is not defined. Run the Phase 2 benchmark cell first "
            "(the one that builds P2 / P2_ALL)."
        )
if "y_test" not in globals():
    raise NameError("y_test is not defined. Run the data split/evaluation setup cells first.")

fs_list = list(P2.keys())
mnames = list(next(iter(P2.values())).keys())

kappa_rows = []
for fs_name in fs_list:
    for mn in mnames:
        y_pred = P2[fs_name][mn]["y_pred"]
        kappa  = cohen_kappa_score(y_test, y_pred)
        kappa_rows.append({
            "Feature Set": fs_name,
            "Model":       mn,
            "Kappa (κ)":   round(kappa, 4),
            "Accuracy":    round(P2[fs_name][mn]["acc"],  4),
            "F1-macro":    round(P2[fs_name][mn]["f1m"],  4),
        })

kappa_df = (pd.DataFrame(kappa_rows)
              .sort_values("Kappa (κ)", ascending=False)
              .reset_index(drop=True))
kappa_df.index += 1

print("Cohen's Kappa — all configurations (split test, sorted):")
display(kappa_df)

# ── Kappa heatmap ─────────────────────────────────────────────────────────
kappa_pivot = kappa_df.pivot_table(index="Feature Set", columns="Model",
                                    values="Kappa (κ)", aggfunc="first")

fig, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(kappa_pivot, ax=ax, annot=True, fmt=".3f", cmap="YlGnBu",
            vmin=0.5, vmax=1.0, linewidths=0.5, cbar_kws={"label": "Cohen's κ"})
ax.set_title("Cohen's Kappa — Feature Set × Model (split test)", fontsize=12, fontweight="bold")
ax.tick_params(axis="x", rotation=0)
ax.tick_params(axis="y", rotation=0)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "kappa_heatmap.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: kappa_heatmap.png")

# %% [markdown]
# ### 15b. Bootstrap Confidence Intervals (95% CI)
#
# **Bootstrap resampling** estimates the sampling distribution of a metric by drawing
# N = 2000 samples **with replacement** from the test set predictions.
#
# - **CI Lower / Upper**: the 2.5th and 97.5th percentiles of the bootstrapped distribution
# - **Bootstrap Mean**: robust central tendency estimate that accounts for sampling variability
#
# This directly replicates the statistical analysis used in NeuroBlend-3 (Table 5).

# %%
# ── Bootstrap CI for all (Feature Set × Model) on split test ──────────────
# scipy.stats.bootstrap takes a function that maps (y_true_sample, y_pred_sample) → scalar.
# We resample INDICES jointly to keep (true, pred) pairs aligned.

N_BOOT    = 2000    # number of bootstrap resamples (2000 is standard)
CI_LEVEL  = 0.95    # 95% confidence interval
BOOT_SEED = SEED

def _boot_f1(indices):
    # Compute F1-macro on the bootstrap-selected subset of predictions.
    return f1_score(y_test[indices], y_pred_boot[indices],
                    average="macro", zero_division=0)

def _boot_acc(indices):
    # Compute accuracy on the bootstrap-selected subset.
    return accuracy_score(y_test[indices], y_pred_boot[indices])

boot_rows = []

for fs_name in fs_list:
    for mn in mnames:
        y_pred_boot = P2[fs_name][mn]["y_pred"]  # global used inside _boot_f1/_boot_acc
        idx_pool    = np.arange(len(y_test))

        # ── F1-macro bootstrap ─────────────────────────────────────────────
        res_f1 = scipy_bootstrap(
            (idx_pool,),                    # pass indices as a tuple
            lambda idx: _boot_f1(idx),
            n_resamples=N_BOOT,
            confidence_level=CI_LEVEL,
            method="percentile",
            random_state=BOOT_SEED,
        )
        # ── Accuracy bootstrap ────────────────────────────────────────────
        res_acc = scipy_bootstrap(
            (idx_pool,),
            lambda idx: _boot_acc(idx),
            n_resamples=N_BOOT,
            confidence_level=CI_LEVEL,
            method="percentile",
            random_state=BOOT_SEED,
        )

        # Bootstrap mean = mean of the resampled distribution
        f1_values  = res_f1.bootstrap_distribution
        acc_values = res_acc.bootstrap_distribution

        boot_rows.append({
            "Feature Set":      fs_name,
            "Model":            mn,
            "F1-macro":         round(P2[fs_name][mn]["f1m"], 4),
            "F1 CI Lower":      round(float(res_f1.confidence_interval.low),  4),
            "F1 CI Upper":      round(float(res_f1.confidence_interval.high), 4),
            "F1 Boot Mean":     round(float(f1_values.mean()),  4),
            "F1 Boot Std":      round(float(f1_values.std()),   4),
            "Accuracy":         round(P2[fs_name][mn]["acc"],   4),
            "Acc CI Lower":     round(float(res_acc.confidence_interval.low),  4),
            "Acc CI Upper":     round(float(res_acc.confidence_interval.high), 4),
            "Acc Boot Mean":    round(float(acc_values.mean()), 4),
            "Acc Boot Std":     round(float(acc_values.std()),  4),
        })
        print(f"  {fs_name:18s} | {mn:3s} | F1={boot_rows[-1]['F1-macro']:.4f} "
              f"CI=[{boot_rows[-1]['F1 CI Lower']:.4f}, {boot_rows[-1]['F1 CI Upper']:.4f}] "
              f"boot_mean={boot_rows[-1]['F1 Boot Mean']:.4f}")

boot_df = (pd.DataFrame(boot_rows)
             .sort_values("F1-macro", ascending=False)
             .reset_index(drop=True))
boot_df.index += 1

print("\nBootstrap CI (95%) — all configurations:")
display(boot_df)
boot_df.to_csv("bootstrap_ci_results.csv", index=False)
print("Saved: bootstrap_ci_results.csv")

# %%
# ── Visualise CI for the best feature set ──────────────────────────────────
best_fs_boot = boot_df.iloc[0]["Feature Set"]
sub = boot_df[boot_df["Feature Set"] == best_fs_boot].copy()

fig, ax = plt.subplots(figsize=(8, 4.5))
colors = [PALETTE[m] for m in sub["Model"]]
x = np.arange(len(sub))

ax.bar(x, sub["F1-macro"], color=colors, alpha=0.85, edgecolor="white", label="F1-macro (observed)")
ax.errorbar(x, sub["F1 Boot Mean"],
            yerr=[sub["F1 Boot Mean"] - sub["F1 CI Lower"],
                  sub["F1 CI Upper"] - sub["F1 Boot Mean"]],
            fmt="none", color="black", capsize=6, linewidth=2,
            label="Bootstrap Mean ± 95% CI")

ax.set_xticks(x)
ax.set_xticklabels(sub["Model"])
ax.set_ylim(0.5, 1.05)
ax.set_ylabel("F1-macro")
ax.set_title(f"Bootstrap 95% CI — {best_fs_boot}", fontsize=12, fontweight="bold")
ax.legend(fontsize=9)
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "bootstrap_ci_best_fs.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: bootstrap_ci_best_fs.png")

# %% [markdown]
# ### 15c. Cross-Validation Fold Statistics
#
# For each (Feature Set × Model) pair we compute:
# - **Mean F1-macro** across all available CV folds
# - **Standard deviation** — measures consistency across partitions
# - **95% CI** — computed from the t-distribution: mean ± t(α/2, df) × std/√n
#
# A small standard deviation means the model is **stable** regardless of which samples land in the test fold.

# %%
# ── Build per-fold statistics from P2_ALL ─────────────────────────────────
# P2_ALL[mode][feature_set][model] contains results for every eval mode.
# We collect all cv_* modes and compute statistics across folds.

from scipy.stats import t as t_dist

cv_modes = [m for m in EVAL_MODES if m.startswith("cv_")]

cv_stat_rows = []

for fs_name in fs_list:
    for mn in mnames:
        f1_folds  = []
        acc_folds = []

        for mode in cv_modes:
            if mode in P2_ALL and fs_name in P2_ALL[mode] and mn in P2_ALL[mode][fs_name]:
                r = P2_ALL[mode][fs_name][mn]
                f1_folds.append(r["f1m"])
                acc_folds.append(r["acc"])

        if len(f1_folds) < 2:
            continue   # need at least 2 folds for std/CI

        f1_arr  = np.array(f1_folds)
        acc_arr = np.array(acc_folds)
        n       = len(f1_arr)
        df_t    = n - 1                                  # degrees of freedom
        t_crit  = t_dist.ppf(0.975, df=df_t)            # two-tailed 95% CI

        f1_mean  = f1_arr.mean()
        f1_std   = f1_arr.std(ddof=1)
        f1_ci_w  = t_crit * f1_std / np.sqrt(n)         # half-width of CI

        acc_mean = acc_arr.mean()
        acc_std  = acc_arr.std(ddof=1)
        acc_ci_w = t_crit * acc_std / np.sqrt(n)

        cv_stat_rows.append({
            "Feature Set":   fs_name,
            "Model":         mn,
            "N folds":       n,
            "F1 Mean":       round(f1_mean,  4),
            "F1 Std":        round(f1_std,   4),
            "F1 CI Lower":   round(f1_mean - f1_ci_w, 4),
            "F1 CI Upper":   round(f1_mean + f1_ci_w, 4),
            "Acc Mean":      round(acc_mean, 4),
            "Acc Std":       round(acc_std,  4),
            "Acc CI Lower":  round(acc_mean - acc_ci_w, 4),
            "Acc CI Upper":  round(acc_mean + acc_ci_w, 4),
        })

cv_stat_df = (pd.DataFrame(cv_stat_rows)
                .sort_values("F1 Mean", ascending=False)
                .reset_index(drop=True))
cv_stat_df.index += 1

print(f"CV fold statistics ({len(cv_modes)} folds: {cv_modes}):")
display(cv_stat_df)
cv_stat_df.to_csv("cv_fold_statistics.csv", index=False)
print("Saved: cv_fold_statistics.csv")

# %%
# ── Plot: Mean ± Std across CV folds for Full(opt) ────────────────────────
sub_cv = cv_stat_df[cv_stat_df["Feature Set"] == "Full(opt)"].copy()

if len(sub_cv) == 0:
    print("No CV fold data for Full(opt) — skipping plot.")
else:
    fig, ax = plt.subplots(figsize=(8, 5))
    x       = np.arange(len(sub_cv))
    colors  = [PALETTE[m] for m in sub_cv["Model"]]

    bars = ax.bar(x, sub_cv["F1 Mean"], color=colors, alpha=0.85,
                  edgecolor="white", linewidth=0.5)
    ax.errorbar(x, sub_cv["F1 Mean"],
                yerr=sub_cv["F1 Std"],
                fmt="none", color="black", capsize=6, linewidth=2,
                label="Mean ± Std")
    ax.fill_between(x,
                    sub_cv["F1 CI Lower"].values,
                    sub_cv["F1 CI Upper"].values,
                    alpha=0.18, color="steelblue", label="95% CI (t-dist)")

    ax.set_xticks(x)
    ax.set_xticklabels(sub_cv["Model"])
    ax.set_ylim(0.5, 1.05)
    ax.set_ylabel("F1-macro")
    ax.set_title("CV Fold Statistics — Full(opt): Mean ± Std ± 95% CI",
                 fontsize=12, fontweight="bold")
    ax.legend(fontsize=9)
    ax.grid(axis="y", alpha=0.3)
    for bar, val in zip(bars, sub_cv["F1 Mean"]):
        ax.text(bar.get_x() + bar.get_width()/2, val + 0.005,
                f"{val:.4f}", ha="center", va="bottom", fontsize=9)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "cv_fold_statistics.png", dpi=120, bbox_inches="tight")
    plt.show()
    print("Saved: cv_fold_statistics.png")

# %% [markdown]
# ### 15d. McNemar's Test (Pairwise Classifier Comparison)
#
# **McNemar's test** is the standard statistical significance test for comparing two classifiers
# on the **same test set**. It examines whether the two models make **different errors** on
# different samples, not just whether their accuracy numbers differ.
#
# **Null hypothesis H₀:** The two classifiers have the same error rate on the test population.
#
# The contingency table counts:
# - **n₀₁**: samples where classifier A is correct but B is wrong
# - **n₁₀**: samples where classifier B is correct but A is wrong
#
# If p < 0.05, the difference between the two classifiers is **statistically significant**.

# %%
# ── McNemar's test between all pairs of classifiers (best feature set) ──────
# We test on Full(opt) predictions since that is the best feature set.

from itertools import combinations

def mcnemar_test(y_true, y_pred_a, y_pred_b):
    """
    McNemar's test with continuity correction (Edwards, 1948).

    Contingency table:
        n00 = both correct   | n01 = A correct,  B wrong
        n10 = A wrong, B correct | n11 = both wrong

    Test statistic (with continuity correction):
        χ² = (|n01 - n10| - 1)² / (n01 + n10)
    p-value from χ²(df=1) distribution.
    """
    correct_a = (y_pred_a == y_true)
    correct_b = (y_pred_b == y_true)

    n00 = int(( correct_a &  correct_b).sum())
    n01 = int(( correct_a & ~correct_b).sum())   # A right, B wrong
    n10 = int((~correct_a &  correct_b).sum())   # A wrong, B right
    n11 = int((~correct_a & ~correct_b).sum())

    # McNemar statistic with continuity correction
    denom = n01 + n10
    if denom == 0:
        return 1.0, n00, n01, n10, n11   # identical predictions → p=1

    chi2 = (abs(n01 - n10) - 1) ** 2 / denom
    from scipy.stats import chi2 as chi2_dist
    p_val = chi2_dist.sf(chi2, df=1)    # survival function = 1 - CDF

    return float(p_val), n00, n01, n10, n11


# Run for Full(opt) across all model pairs
TARGET_FS_MC = "Full(opt)"
preds = {mn: P2[TARGET_FS_MC][mn]["y_pred"] for mn in mnames}

mcnemar_rows = []
for (a, b) in combinations(mnames, 2):
    p, n00, n01, n10, n11 = mcnemar_test(y_test, preds[a], preds[b])
    mcnemar_rows.append({
        "Model A":          a,
        "Model B":          b,
        "n₀₁ (A✓ B✗)":     n01,
        "n₁₀ (A✗ B✓)":     n10,
        "p-value":          round(p, 6),
        "Significant (p<0.05)": "✓ Yes" if p < 0.05 else "✗ No",
        "Interpretation":   ("A is significantly better than B" if n01 > n10 and p < 0.05
                             else "B is significantly better than A" if n10 > n01 and p < 0.05
                             else "No significant difference"),
    })

mcnemar_df = pd.DataFrame(mcnemar_rows)
print(f"McNemar's test (continuity corrected) — feature set: {TARGET_FS_MC}")
display(mcnemar_df)
mcnemar_df.to_csv("mcnemar_test_results.csv", index=False)
print("Saved: mcnemar_test_results.csv")

# ── p-value matrix heatmap ─────────────────────────────────────────────────
p_matrix = pd.DataFrame(np.eye(len(mnames)), index=mnames, columns=mnames)
for row in mcnemar_rows:
    p_matrix.loc[row["Model A"], row["Model B"]] = row["p-value"]
    p_matrix.loc[row["Model B"], row["Model A"]] = row["p-value"]

fig, ax = plt.subplots(figsize=(6, 5))
mask = np.eye(len(mnames), dtype=bool)   # mask diagonal (always p=1)
sns.heatmap(p_matrix.astype(float), ax=ax, annot=True, fmt=".4f",
            cmap="RdYlGn_r", vmin=0, vmax=0.1, linewidths=1,
            mask=mask, cbar_kws={"label": "p-value"})
ax.set_title(f"McNemar's Test — p-value Matrix\n({TARGET_FS_MC})",
             fontsize=12, fontweight="bold")
# Draw red threshold line annotation
ax.text(0.5, -0.12, "Red = significant (p < 0.05)  |  Green = not significant",
        transform=ax.transAxes, ha="center", fontsize=9, color="gray")
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "mcnemar_pvalue_matrix.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: mcnemar_pvalue_matrix.png")

# %% [markdown]
# ### 15e. Wilcoxon Signed-Rank Test (Across CV Folds)
#
# The **Wilcoxon signed-rank test** compares two classifiers across multiple CV folds in a
# **paired, non-parametric** way. It is the recommended alternative to a paired t-test when
# the distribution of per-fold score differences cannot be assumed to be normal.
#
# **Why Wilcoxon instead of t-test?**
# With only 5 CV folds, the Central Limit Theorem does not apply reliably. Wilcoxon makes
# no assumption about normality — it ranks the absolute differences and tests whether they
# are symmetrically distributed around zero.
#
# **Null hypothesis H₀:** The median of per-fold F1 differences is zero (models are equivalent).

# %%
# ── Wilcoxon signed-rank test between all classifier pairs across CV folds ──
# Collect per-fold F1-macro for each (feature_set, model) combination.

def get_cv_scores(fs_name, mn):
    """Return list of CV fold F1-macro values for a given (fs, model) pair."""
    scores = []
    for mode in cv_modes:
        if mode in P2_ALL and fs_name in P2_ALL[mode] and mn in P2_ALL[mode][fs_name]:
            scores.append(P2_ALL[mode][fs_name][mn]["f1m"])
    return scores


wilcoxon_rows = []

for fs_name in fs_list:
    for (a, b) in combinations(mnames, 2):
        scores_a = get_cv_scores(fs_name, a)
        scores_b = get_cv_scores(fs_name, b)

        # Both must have equal number of folds for a paired test
        n_common = min(len(scores_a), len(scores_b))
        if n_common < 3:
            # Wilcoxon requires at least 3 pairs (n_pairs = number of non-zero diffs)
            continue

        scores_a = np.array(scores_a[:n_common])
        scores_b = np.array(scores_b[:n_common])
        diffs    = scores_a - scores_b

        # If all differences are zero the test cannot be run
        if np.all(diffs == 0):
            p = 1.0
            statistic = 0.0
        else:
            try:
                statistic, p = wilcoxon(scores_a, scores_b,
                                        alternative="two-sided",
                                        zero_method="wilcox")
            except ValueError:
                p, statistic = 1.0, 0.0

        wilcoxon_rows.append({
            "Feature Set":           fs_name,
            "Model A":               a,
            "Model B":               b,
            "A mean F1":             round(scores_a.mean(), 4),
            "B mean F1":             round(scores_b.mean(), 4),
            "Mean diff (A−B)":       round(diffs.mean(), 4),
            "W statistic":           round(statistic, 4),
            "p-value":               round(p, 6),
            "Significant (p<0.05)":  "✓ Yes" if p < 0.05 else "✗ No",
        })

wilcoxon_df = (pd.DataFrame(wilcoxon_rows)
                 .sort_values("p-value")
                 .reset_index(drop=True))
wilcoxon_df.index += 1

print(f"Wilcoxon signed-rank test ({n_common} CV folds):")
display(wilcoxon_df)
wilcoxon_df.to_csv("wilcoxon_test_results.csv", index=False)
print("Saved: wilcoxon_test_results.csv")

# Highlight significant differences
sig_count = (wilcoxon_df["Significant (p<0.05)"] == "✓ Yes").sum()
print(f"\n{sig_count} / {len(wilcoxon_df)} comparisons show significant differences (p < 0.05)")

# %% [markdown]
# ### 15f. Friedman Test + Post-Hoc Nemenyi Test
#
# The **Friedman test** is a non-parametric equivalent of the one-way repeated-measures ANOVA.
# It tests whether at least one of k classifiers performs significantly differently from the others,
# using the CV fold scores as "blocks."
#
# **If the Friedman test is significant (p < 0.05),** the **post-hoc Nemenyi test** identifies
# *which pairs* of classifiers are significantly different, controlling for multiple comparisons.
#
# This is the **gold standard** for comparing multiple classifiers on multiple datasets/folds
# (Demšar, 2006 — "Statistical Comparisons of Classifiers over Multiple Data Sets").

# %%
# ── Friedman test across all classifiers on each feature set ──────────────
# The test requires a matrix of shape (n_blocks × n_classifiers)
# where rows = CV folds and columns = classifiers.

print("=" * 60)
print("FRIEDMAN TEST — Comparing SVM, KNN, RF across CV folds")
print("=" * 60)

friedman_rows = []
nemenyi_results = {}

for fs_name in fs_list:
    cv_matrix = []
    models_present = []

    for mn in mnames:
        scores = get_cv_scores(fs_name, mn)
        if len(scores) >= 3:
            cv_matrix.append(scores[:min(len(s) for s in [get_cv_scores(fs_name, m)
                                         for m in mnames if len(get_cv_scores(fs_name, m)) > 0])])
            models_present.append(mn)

    if len(models_present) < 2:
        continue

    # Ensure all models have the same number of folds (use minimum)
    min_folds = min(len(s) for s in cv_matrix)
    cv_arr = np.array([s[:min_folds] for s in cv_matrix])  # shape: (n_models, n_folds)

    # Friedman test requires rows=folds, cols=classifiers → transpose
    cv_arr_t = cv_arr.T   # shape: (n_folds, n_models)

    if cv_arr_t.shape[0] < 2:
        continue

    try:
        stat, p_friedman = friedmanchisquare(*[cv_arr_t[:, j] for j in range(cv_arr_t.shape[1])])
    except Exception:
        continue

    friedman_rows.append({
        "Feature Set":           fs_name,
        "N folds":               min_folds,
        "Friedman statistic":    round(stat, 4),
        "p-value":               round(p_friedman, 6),
        "Significant (p<0.05)":  "✓ Yes" if p_friedman < 0.05 else "✗ No",
        "Models compared":       ", ".join(models_present),
    })

    # ── Post-hoc Nemenyi (only if Friedman significant) ──────────────────
    if p_friedman < 0.05:
        # Build DataFrame for scikit-posthocs
        data_list = []
        for j, mn in enumerate(models_present):
            for fold_score in cv_arr_t[:, j]:
                data_list.append({"model": mn, "score": fold_score})
        data_ph = pd.DataFrame(data_list)
        try:
            nemenyi_p = sp.posthoc_nemenyi_friedman(
                data_ph, melted=True, block_col=None,
                group_col="model", y_col="score"
            )
            nemenyi_results[fs_name] = nemenyi_p
        except Exception:
            pass
    else:
        print(f"  {fs_name}: Friedman p={p_friedman:.4f} — no post-hoc needed (H₀ not rejected)")

friedman_df = pd.DataFrame(friedman_rows).reset_index(drop=True)
friedman_df.index += 1

print("\nFriedman test results:")
display(friedman_df)
friedman_df.to_csv("friedman_test_results.csv", index=False)
print("Saved: friedman_test_results.csv")

# ── Plot Friedman p-values ────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(11, 4.5))
colors = ["tomato" if sig == "✓ Yes" else "steelblue"
          for sig in friedman_df["Significant (p<0.05)"]]
bars = ax.bar(friedman_df["Feature Set"], friedman_df["p-value"],
              color=colors, edgecolor="white")
ax.axhline(0.05, color="red", ls="--", lw=1.5, label="α = 0.05")
ax.set_ylabel("Friedman p-value")
ax.set_title("Friedman Test — p-value per Feature Set\n(Red = significant difference between classifiers)",
             fontsize=12, fontweight="bold")
ax.set_xticklabels(friedman_df["Feature Set"], rotation=25, ha="right", fontsize=9)
ax.bar_label(bars, fmt="%.4f", fontsize=8, padding=2)
ax.legend(fontsize=9)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "friedman_pvalues.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: friedman_pvalues.png")

# %%
# ── Nemenyi post-hoc heatmaps (for significant Friedman results) ──────────
if len(nemenyi_results) == 0:
    print("No significant Friedman results — no post-hoc Nemenyi plots to show.")
else:
    n_sig = len(nemenyi_results)
    fig, axes = plt.subplots(1, n_sig, figsize=(6 * n_sig, 5))
    if n_sig == 1:
        axes = [axes]

    for ax, (fs_name, nemenyi_p) in zip(axes, nemenyi_results.items()):
        mask_diag = np.eye(nemenyi_p.shape[0], dtype=bool)
        sns.heatmap(nemenyi_p, ax=ax, annot=True, fmt=".3f",
                    cmap="RdYlGn_r", vmin=0, vmax=0.1,
                    linewidths=1, mask=mask_diag,
                    cbar_kws={"label": "p-value"})
        ax.set_title(f"Nemenyi post-hoc\n{fs_name}", fontsize=10, fontweight="bold")
        ax.tick_params(axis="x", rotation=30)

    fig.suptitle("Post-hoc Nemenyi Test — Pairwise p-values\n(Red = significant, Green = not significant)",
                 fontsize=12, fontweight="bold")
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "nemenyi_posthoc.png", dpi=120, bbox_inches="tight")
    plt.show()
    print("Saved: nemenyi_posthoc.png")

# %% [markdown]
# ### 15g. Publication-Ready Statistical Summary Table
#
# This table consolidates all statistical validation results for the **best configuration**
# (Full(opt) + best model), following the format of NeuroBlend-3 (Table 5):
#
# | Column | Meaning |
# |--------|---------|
# | **Accuracy / F1-macro** | Point estimate on split test |
# | **Std** | Standard deviation across CV folds |
# | **CI Lower / CI Upper** | 95% confidence interval (bootstrap) |
# | **Boot Mean** | Bootstrap mean estimate |
# | **κ (Kappa)** | Cohen's Kappa on split test |

# %%
# ── Build publication-ready summary table ─────────────────────────────────
# Merge: (1) split metrics, (2) bootstrap CI, (3) CV std, (4) Cohen's Kappa

summary_rows = []

for fs_name in fs_list:
    for mn in mnames:
        # 1. Split test metrics
        sp = P2[fs_name][mn]

        # 2. Bootstrap CI
        bc = boot_df[(boot_df["Feature Set"] == fs_name) & (boot_df["Model"] == mn)]
        if bc.empty:
            continue
        bc = bc.iloc[0]

        # 3. CV std
        cs = cv_stat_df[(cv_stat_df["Feature Set"] == fs_name) & (cv_stat_df["Model"] == mn)]
        f1_std_cv  = cs.iloc[0]["F1 Std"]  if not cs.empty else float("nan")
        acc_std_cv = cs.iloc[0]["Acc Std"] if not cs.empty else float("nan")

        # 4. Cohen's Kappa
        kc = kappa_df[(kappa_df["Feature Set"] == fs_name) & (kappa_df["Model"] == mn)]
        kappa_val = kc.iloc[0]["Kappa (κ)"] if not kc.empty else float("nan")

        summary_rows.append({
            "Feature Set":   fs_name,
            "Model":         mn,
            "Accuracy":      round(sp["acc"], 4),
            "Acc Std (CV)":  round(acc_std_cv, 4),
            "Acc CI Low":    round(bc["Acc CI Lower"], 4),
            "Acc CI High":   round(bc["Acc CI Upper"], 4),
            "F1-macro":      round(sp["f1m"], 4),
            "F1 Std (CV)":   round(f1_std_cv, 4),
            "F1 CI Low":     round(bc["F1 CI Lower"], 4),
            "F1 CI High":    round(bc["F1 CI Upper"], 4),
            "F1 Boot Mean":  round(bc["F1 Boot Mean"], 4),
            "κ (Kappa)":     kappa_val,
            "Precision":     round(sp["prec"], 4),
            "Recall":        round(sp["rec"],  4),
        })

summary_df = (pd.DataFrame(summary_rows)
                .sort_values("F1-macro", ascending=False)
                .reset_index(drop=True))
summary_df.index += 1

print("PUBLICATION-READY STATISTICAL SUMMARY TABLE")
print("=" * 100)
display(summary_df)

summary_df.to_csv("statistical_validation_summary.csv", index=False)
print("Saved: statistical_validation_summary.csv")

# ── Print best configuration in NeuroBlend-3 style ────────────────────────
best_row = summary_df.iloc[0]
print("\n" + "=" * 65)
print("BEST CONFIGURATION — Statistical Summary")
print("=" * 65)
print(f"  Feature Set  : {best_row['Feature Set']}")
print(f"  Model        : {best_row['Model']}")
print(f"  Accuracy     : {best_row['Accuracy']:.4f}  (±{best_row['Acc Std (CV)']:.4f})")
print(f"  Acc 95% CI   : [{best_row['Acc CI Low']:.4f}, {best_row['Acc CI High']:.4f}]")
print(f"  F1-macro     : {best_row['F1-macro']:.4f}  (±{best_row['F1 Std (CV)']:.4f})")
print(f"  F1 95% CI    : [{best_row['F1 CI Low']:.4f}, {best_row['F1 CI High']:.4f}]")
print(f"  F1 Boot Mean : {best_row['F1 Boot Mean']:.4f}")
print(f"  Cohen's κ    : {best_row['κ (Kappa)']:.4f}")
print(f"  Precision    : {best_row['Precision']:.4f}")
print(f"  Recall       : {best_row['Recall']:.4f}")

# %%
# ── Final visual summary: strip-plot + CI bars for top configurations ──────
# Show top-10 configurations with error bars (CI) and κ annotation

top10 = summary_df.head(10).copy()

fig, axes = plt.subplots(1, 2, figsize=(17, 6))
fig.suptitle("Statistical Validation Summary — Top 10 Configurations",
             fontsize=13, fontweight="bold")

# Left: F1-macro + 95% CI
ax = axes[0]
y_pos = np.arange(len(top10))[::-1]
bar_cols = [PALETTE[m] for m in top10["Model"]]
ax.barh(y_pos, top10["F1-macro"], color=bar_cols, alpha=0.8, edgecolor="white")
ax.errorbar(top10["F1-macro"].values, y_pos,
            xerr=[top10["F1-macro"].values - top10["F1 CI Low"].values,
                  top10["F1 CI High"].values - top10["F1-macro"].values],
            fmt="none", color="black", capsize=4, linewidth=1.5)
ax.set_yticks(y_pos)
ax.set_yticklabels([f"{r['Feature Set']} | {r['Model']}"
                    for _, r in top10.iterrows()], fontsize=8)
ax.set_xlabel("F1-macro (with 95% CI)")
ax.set_title("F1-macro + Bootstrap 95% CI")
ax.set_xlim(0.4, 1.05)
ax.axvline(0.9, color="gray", ls="--", lw=1, alpha=0.5)

from matplotlib.patches import Patch
ax.legend(handles=[Patch(facecolor=PALETTE[m], label=m) for m in mnames],
          fontsize=9, loc="lower right")

# Right: Cohen's Kappa
ax2 = axes[1]
kappa_colors = ["#2196F3" if k > 0.8 else "#FF9800" if k > 0.6 else "#F44336"
                for k in top10["κ (Kappa)"]]
bars2 = ax2.barh(y_pos, top10["κ (Kappa)"], color=kappa_colors, alpha=0.85, edgecolor="white")
ax2.set_yticks(y_pos)
ax2.set_yticklabels([f"{r['Feature Set']} | {r['Model']}"
                     for _, r in top10.iterrows()], fontsize=8)
ax2.set_xlabel("Cohen's κ")
ax2.set_title("Cohen's Kappa (κ)")
ax2.set_xlim(0.4, 1.05)
ax2.axvline(0.8, color="blue",  ls="--", lw=1, alpha=0.5, label="κ=0.80 (almost perfect)")
ax2.axvline(0.6, color="orange",ls="--", lw=1, alpha=0.5, label="κ=0.60 (substantial)")
ax2.bar_label(bars2, fmt="%.3f", fontsize=8, padding=2)
ax2.legend(fontsize=8, loc="lower right")

plt.tight_layout()
plt.savefig(OUTPUT_DIR / "statistical_validation_summary.png", dpi=120, bbox_inches="tight")
plt.show()
print("Saved: statistical_validation_summary.png")

print("\n" + "=" * 65)
print("SECTION 15 COMPLETE — Files saved:")
for f in ["bootstrap_ci_results.csv", "cv_fold_statistics.csv",
          "mcnemar_test_results.csv", "wilcoxon_test_results.csv",
          "friedman_test_results.csv", "statistical_validation_summary.csv",
          "kappa_heatmap.png", "bootstrap_ci_best_fs.png",
          "cv_fold_statistics.png", "mcnemar_pvalue_matrix.png",
          "friedman_pvalues.png", "nemenyi_posthoc.png",
          "statistical_validation_summary.png"]:
    print(f"  {f}")
